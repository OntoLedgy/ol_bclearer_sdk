# %% [markdown]
# # Load SiGraph Database to Neo4j
#
# ## Core Concepts
#
# ### Load a sigraph db xml file
# * The binary zip file is read and send to neo4j and parsed with apoc.load.xml which is capable of getting a zip file as input
# * The XML is parsed to json and from that the following structure is made <br/> (Database)-[:HAS_FILE]->(File)-[:HAS_ALLOCATION]->(Allocation)
# * The Allocation has a allocKey comprised of dbname + "_" + fileName + "_" + allocation.oid
# * The parsed to json xml part of the Alllocation is saved on the Allocation Node
#
# ### Process Allocation json XML structure
# * The Allocation gets the dynClass as a Label if available, otherwise the statClass is used
# * All the xml classes and their members below the Allocation xml will be 'flattened' on the Allocation node
# * When there are complex member properties then a 'dot' notation is used
#   ```
#   position.Geo_point.x: 16.00000000
#   ```
#   This is needed when an Allocation has more 'x' values in the member structure
# * In the case of successor and predecessor xlink:href reference only the successor is taken (predecessor is skipped) to create the IS_SUCCESSOR relationship
# * All other xlink:href references are processed.
#     * The xml element name of the element with the xlink:href attribute is used to create the relationship type. When there is a scoped element (local/remote) the element name of the element with the scope attribute is used.
# * When there are no values then the 'property name' is stored on the '_emptyProps' property on an Allocation. example
#   ```
#   _emptyProps: Pobject,Occurrence_Frame_occ.Frame_occ,Attached_graphic_container_Graphic,attached_ud_occs,attached_ud_occs_std_txt,position.Geo_point.Geo_object.Pobject,Conn_point_occ_Conn_segm_occ,Conn_point_occ_Conn_segm_occ.Conn_segm_occ,Pin_occ_Function_pin.Function_pin,El_pin_occ_Singleline_occ.Singleline_occ,El_pin_occ_Legend_occ.Legend_occ
#   ```
#
# ## Neo4j configuration
#
# ### Memory settings
# The process is memory intensive so you will need to assign a proper amount of memory to the neo4j process
# The following settings are good to use (below is the minimal settings, better is a heap of 16G and a pagecache of 2G) :
# ```
# dbms.memory.heap.initial_size=6G
# dbms.memory.heap.max_size=6G
# dbms.memory.pagecache.size=2G
# ```
# Note this is enough to run one database loads at the same time. When you want to do 4 at the same time then you need also more memory reserved. Of course you need to have at least 4 cpu available for the neo4j server.
#
# ### transaction log settings
# This is for development only. When you are loading big datasets multiple times this will be a big write operation for the database. The default is tx log retention is 2 days. Which means that the tx log files will be kept for two days. With very intensive loads in dev environment you will end up with a lot of gigabites of tx log data.
#
# ```
# # dev only!!!
# db.tx_log.rotation.retention_policy=1G size
# ```
# With this setting the tx log on disk will not grow bigger then ~1.5G
# See for more information here: https://neo4j.com/docs/operations-manual/current/configuration/configuration-settings/#config_db.tx_log.rotation.retention_policy

# %%
# initialising
import os
import sys

sys.path.append("../")

# python driver object

from neo4j import GraphDatabase

# simple utility voor het afvuren van cypher statements
from neo4jutils import *

# %%
# settings
isDebug = False
isInfo = False
# The uri to connect to the database
dburi = "neo4j://localhost:7687"
dbusr = "neo4j"
dbpwd = "neoneoneo"
# The database name where the data must be loaded to
dbname = "rxml"
cypherOutput = "none"
# to process all the files for a database use
# fileFilter = '.xml.gz'
fileFilter = ".xml.gz"
noValueString = "null"
# when True all the empty member elements become properties with the value "null"
# my advice use False here because the empty elements are now kept in the _emptyProps property on a node
useNoValueString = False

# %%
# connect to the database and get the driver object
#
driver = GraphDatabase.driver(dburi, auth=(dbusr,dbpwd ))

# %%
# db session
session = driver.session(database=dbname)

# %%
# function to do output
def pdebug(msg):
    if isDebug == True:
        print(msg)

def pinfo(msg):
    if isInfo == True:
        print(msg)


# function to read a file and return the binary object
def readXMLFileBinary(path):
    # print("readXMLFile file " + path)
    bfile = open(path, "rb")
    xmlgz = bfile.read()
    # print(" compressed length: " + str(len(xmlgz)) )
    return xmlgz

# %%
def get_file_name(file_path):
    return file_path.split("/")[-1]

# %%
# the storage_interop_services_source directory
sourceDir = "/Users/keesv/work/bClearer/sigraph/xml-data/"
#dbDirNames = ["content_A_E/AE_2016R3"
#             ]
# "R_2016R3",
dbDirNames = ["R_2016R3",
             ]
#              ,"content_A_E/AE_2016R3"
#              ,"content_F_I/F_2016R3"
#              ,"content_F_I/F_SPS_2016R3"
#              ,"content_F_I/G_2016R3"
#              ,"content_F_I/HK_E_2016R3"
#              ,"content_F_I/HK_MSR_2016R3"
#              ,"content_F_I/HR_2016R3"
#              ,"content_F_I/HSA090_2016R3"
#              ,"content_F_I/HSA100_2016R3"
#              ,"content_F_I/HSA250_2016R3"
#              ,"content_F_I/HSA280_2016R3"
#              ,"content_F_I/ICI_2016R3"
#              ,"content_F_I/IH2-E_2016R3"
#              ,"content_F_I/IMS_2016R3"
#              ,"content_F_I/IS_2016R3"
#              ,"content_F_I/I_2016R3"

# %%
# creating constraints
# run_cypher(session,"CREATE CONSTRAINT ukSource IF NOT EXISTS FOR (n:Source) REQUIRE n.key IS UNIQUE")
run_cypher(session,"CREATE CONSTRAINT ukAllocation IF NOT EXISTS FOR (n:Allocation) REQUIRE n.allocKey IS UNIQUE")
run_cypher(session,"CREATE CONSTRAINT ukDatabase IF NOT EXISTS FOR (n:Database) REQUIRE n.name IS UNIQUE")
run_cypher(session,"CREATE INDEX indOID IF NOT EXISTS FOR (n:Allocation) ON (n.oid) ")
# Out:
# run_cypher : CREATE CONSTRAINT ukAllocation IF NOT EXISTS FOR (n:Allocation) REQUIRE n.al...
# (no changes, no records)
# run_cypher : CREATE CONSTRAINT ukDatabase IF NOT EXISTS FOR (n:Database) REQUIRE n.name I...
# (no changes, no records)
# run_cypher : CREATE INDEX indOID IF NOT EXISTS FOR (n:Allocation) ON (n.oid)...
# (no changes, no records)

# %%
#
# In this block we initialise the structures to process data back to neo4j
#
cychildren = []
# { "parent": parent, "props": {} }
cyparentProperties = {}
# { "parent": parent, labels:[] }
cyparentLabels = {}
cysuccessorRels = []
cyinstanceRels = []
cyOtherRels = []
cyEmptyProps = {}

def clearCy():
    pinfo("clearing the prepared data for neo4j")
    cychildren.clear()
    cyparentProperties.clear()
    cyparentLabels.clear()
    cysuccessorRels.clear()
    cyinstanceRels.clear()
    cyOtherRels.clear()
    cyEmptyProps.clear()

def addChild(rec):
    # for now simple
    # if we gonna use this on a higher level for multiple parents we meed another structure
    # usage   addChild(parent, { "parent": parent, "children" : element['_children'], "order": order , "props": props , "elmType" : elmType }):
    pinfo(f" addChild parent rec : {rec['elmType']}")
    cychildren.append(rec)

def addEmptyProp(parent, aString):
    if aString is not None:
        empProps = []
        if parent in cyEmptyProps:
            empProps = cyEmptyProps[parent]
        if aString not in empProps:
            empProps.append(aString)
        cyEmptyProps[parent] = empProps

def addNodeProps(parent, props):
    # {"parent",{props:props}}
    if props is not None:
        parentProps = {}
        if parent in cyparentProperties:
            parentProps = cyparentProperties[parent]
        for key in props.keys():
            parentProps[key] = props[key]
        cyparentProperties[parent] = parentProps

def addNodeLabel(parent, label):
    if label is not None:
        labels = []
        if parent in cyparentLabels:
            labels = cyparentLabels[parent]
        if label not in labels:
            labels.append(label)
        cyparentLabels[parent] = labels

def addSuccessorRel(rec):
    # (parent,{ "parent": parent, "elm": elm, "index" : index, "ref" : ref})
    # the parent is already in the record
    cysuccessorRels.append(rec)

def addInstanceRel(rec):
    # addInstanceRel(parent,{ "parent": parent, "elm": elm, "relProps" : {"rel_name": scopedElement['rel_name'], "dest_attr": scopedElement['dest_attr'] }, "ref" : ref, "rel_type": rel_type })
    cyinstanceRels.append(rec)

def addOtherRel(rec):
    # addOtherRel(parent,{ "parent": parent, "elm": elm, "ref" : ref, "rel_type": rel_type })
    pinfo(f"addOtherRel {rec}")
    cyOtherRels.append(rec)

def processChilds():
    pdebug(f" processChilds start : {len(cychildren)} ")
    # record { "parent": parent, "children" : element['_children'], "order": order , "props": props , "elmType" : elmType }
    if len(cychildren) > 0:
        childCypher = """
           UNWIND $childrecs as row
           MATCH (parent) WHERE elementId(parent) = row.parent 
           CREATE (parent)-[:HAS_CHILD]->(child {order: row.order})
           SET child += row.props
           SET child:PrcElement:PrcStructure
           WITH child, row
           CALL apoc.create.addLabels(child, [row.elmType]) yield node
           WITH child, row
           CALL apoc.convert.setJsonProperty(child, '_children', row.children) 
           RETURN count(*) as cnt
        """
        run_cypher(session, childCypher, { "childrecs":cychildren },cypherOutput)
    else:
        pdebug(" processChilds no children to add ")

def processParentLabelAndProperties():
    pinfo(" processParentProperties start   ")
    # { parent, "props": {} }
    # cyparentProperties = {}
    # { parent, labels:[] }
    # cyparentLabels = {}
    inputrows = []
    propparents = cyparentProperties.keys()
    emptypropparents = cyEmptyProps.keys()
    labelparents = cyparentLabels.keys()

    for key in propparents:
        labels = []
        if key in labelparents:
            labels = cyparentLabels[key]
        prps = cyparentProperties[key]
        if key in emptypropparents:
            prps["_emptyProps"] = cyEmptyProps[key]
        inputrows.append({"parent": key, "props":prps, "labels": labels} )
    for lkey in labelparents:
        if lkey not in propparents:
            lprps = {}
            if lkey in emptypropparents:
                lprps["_emptyProps"] = cyEmptyProps[lkey]
            inputrows.append({"parent": lkey, "props":lprps, "labels": cyparentLabels[lkey]} )

    # should we use apoc.periodic.commit here? the average amount of PrcElement labels < 10000
    updateParentQuery = """
        UNWIND $inputrows AS row
        MATCH (parent) WHERE elementId(parent) = row.parent
        SET parent += row.props
        WITH parent, row
        CALL apoc.create.addLabels(parent, row.labels) YIELD node
        RETURN count(*) AS cnt
    """
    run_cypher(session, updateParentQuery, {"inputrows" : inputrows}, cypherOutput)

def processSuccessorRels():
    pinfo(f" processSuccessorRels start {len(cysuccessorRels)} to process ")

    if len(cysuccessorRels) > 0:
        query = """
            UNWIND $successorRels as row
            MATCH (a:Allocation { allocKey : row.ref })
            WITH a, row
            MATCH (n) where elementId(n) = row.parent
            WITH a, n, row
            MERGE (n)-[r:IS_SUCCESSOR]->(a)
            SET n.type = row.elm
            ,   n.index = row.index
            SET r+= row.relProps
        """
        run_cypher(session, query, { "successorRels": cysuccessorRels },cypherOutput)

def processInstanceRels():
    pinfo(f" instanceRels start {len(cyinstanceRels)} to process")
    if len(cyinstanceRels) > 0:
        # now process the instanceRels
        query = """
           UNWIND $instanceRels as row
           MATCH (a:Allocation { allocKey : row.ref })
           WITH a, row
           MATCH (n) where elementId(n) = row.parent 
           WITH a, n, row
           CALL apoc.create.relationship(n, row.rel_type, row.relProps , a) yield rel
           RETURN count(rel) AS count;
        """
        parameters = {"instanceRels": cyinstanceRels}
        run_cypher(session, query, parameters,cypherOutput)

def processOtherRels():
    pinfo(f" otherRels start {len(cyOtherRels)} to process")
    pdebug(f" otherRels {cyOtherRels} ")
    if len(cyOtherRels) > 0:
        # now process the instanceRels
        query = """
           UNWIND $otherRels as row
           MATCH (a:Allocation { allocKey : row.ref })
           WITH a, row
           MATCH (n) where elementId(n) = row.parent 
           WITH a, n, row
           CALL apoc.create.relationship(n, row.rel_type, row.relProps , a) yield rel
           RETURN count(rel) AS count;
        """
        parameters = {"otherRels": cyOtherRels}
        run_cypher(session, query, parameters, cypherOutput)

def writeToNeo4j(parentIDS):
    pinfo(">>> write to neo in batches ")
    pinfo(f" {len(parentIDS)} PrcElements to process ")
    wtStart = time.perf_counter_ns()
    #
    # remove the PrcElement Label and the _children property from the parent node
    #
    query = """
        UNWIND $parentIds AS pid
        MATCH (parent) WHERE elementId(parent) = pid
        REMOVE parent:PrcElement
        REMOVE parent.`_children`
        RETURN count(*) AS cnt
    """
    run_cypher(session, query, { "parentIds": parentIDS },cypherOutput)
    wt1 = time.perf_counter_ns()
    tremovelabelsduration = ( wt1 - wtStart) // 1000000

    # now we have to update the parent node, e.g. remove the PrcElement label and remove the _chidren property
    processParentLabelAndProperties()
    wt2 = time.perf_counter_ns()
    tprocespropertiesandlabels = ( wt2 - wt1) // 1000000
    # now process the children
    processChilds()
    wt3 = time.perf_counter_ns()
    tproceschilds = ( wt3 - wt2) // 1000000

    # now process the successorRels
    processSuccessorRels()
    wt4 = time.perf_counter_ns()
    tprocesSucessors = ( wt4 - wt3) // 1000000
    # now process the instanceRels
    processInstanceRels()
    wt5 = time.perf_counter_ns()
    tprocesInstanceRels = ( wt5 - wt4) // 1000000
    # now process the OtherRels
    processOtherRels()
    wt6 = time.perf_counter_ns()
    tprocesInstanceRels = ( wt6 - wt5) // 1000000

    wduration = (time.perf_counter_ns() - wtStart) // 1000000
    pinfo(f"""written to neo4j in {wduration} ms :
      - removeLabels {tremovelabelsduration} ms - parentLabelsEnProps {tprocespropertiesandlabels} ms - processChildren {tproceschilds} ms - tprocesSucessors {tprocesSucessors} ms - tprocesInstanceRels {tprocesInstanceRels} ms
    """)
    # now clear the stuff otherwise we get unwanted effects
    clearCy()

# %%
def saveTopStructure(path, src, dbsess):
    params = {"xml": readXMLFileBinary(path) , "storage_interop_services_source": src, "fileName" : get_file_name(path) }
    query = """
    CALL {
    	CALL apoc.load.xml($xml, '//*[starts-with(name(),"xdm")]|//*[starts-with(name(),"xsm")]', {compression: 'GZIP'}, false ) yield value
    	return "member" as xtype, value 
    	UNION 
        CALL apoc.load.xml($xml, '//*[starts-with(name(),"xsc")]', {compression: 'GZIP'}, false ) yield value 
        return "xsc" as xtype, value      
        UNION 
        CALL apoc.load.xml($xml, '//*[starts-with(name(),"xdc")]', {compression: 'GZIP'}, false ) yield value 
        return "xdc" as xtype, value      
    } WITH distinct xtype, value
      WITH collect( CASE WHEN xtype = "member" THEN value._type ELSE null END ) as members
      ,    collect( distinct CASE WHEN xtype = "xsc" THEN value._type END) as staticClasses	
      ,    collect( distinct CASE WHEN xtype = "xdc" THEN value._type END) as dynamicClasses	
      WITH members, staticClasses, dynamicClasses
      MERGE (db:Database {name: $storage_interop_services_source})
      MERGE (db)-[:HAS_FILE]->(file:File {name: $fileName} )
      SET file.members = members
      ,   file.staticClasses = staticClasses
      ,   file.dynamicClasses = dynamicClasses
      WITH file, $storage_interop_services_source as src
       call apoc.load.xml($xml, '/*/*/allocation', {compression: 'GZIP'}, false) yield value 
       with file, src
       , value.stat_class as stC
       , coalesce(value.dyn_class,"") as dynC 
       , src + '_' + file.name + '#' + value.oid as allocationKey
       , value.oid as oid
       , src + '_' + value.ref as ref
       , value._children as children
       , value
       MERGE (allocation:Allocation { allocKey: allocationKey })
       SET allocation.statClass = stC
         , allocation.dynClass = dynC
         , allocation.oid = oid
         , allocation.storage_interop_services_source = src
       MERGE (file)-[:HAS_ALLOCATION]->(allocation)  
       FOREACH ( y in CASE WHEN ref IS NULL THEN [] ELSE [] END |
          MERGE (rAlloc:Allocation { allocKey: ref })
          MERGE (allocation)-[:HAS_REFERENCE_TO]->(rAlloc)
        )
        WITH allocation, children, value 
        SET allocation:PrcElement:PrcStructure 
        WITH children, allocation, value 
        CALL apoc.convert.setJsonProperty(allocation, '_children', case when children is null then [value] else children end)  
       return count(*) as allocationCount
    """
    run_cypher(dbsess, query, params, "none")

# %%
def getKeys(jsonElement):
    keysList = list(jsonElement.keys())
    rrr = []
    for ee in keysList:
        if ee not in skipJSONKeys():
            rrr.append(ee)
    return rrr

# %%
def skipJSONKeys():
    return ["origin", "online"]

# %%
def getAttributes(element):
    # everything except _type and _children and more
    # we use now the element name as prefix for the property(this can be changed according to Mesbah's wishes)
    # to catch the event if you have multiple elements with the same attributes overwriting each other
    dict = {}
    keys = getKeys(element)
    elm = element["_type"]
    for k in keys:
        if k not in ["_type","_children","_text","role","origin","scope"]:
            dict[elm + "__" + k] = element[k]
    return dict

# %%
def hasValues(element, level):
    # check if there are values behind this we look a bit ahead in the xml structure
    # now there are children
    if level == 4:
        return True
    keys = getKeys(element)
    # pdebug(f"\n\nkeys level  {keys}")
    if "_text" in keys:
        return True
    if "_children" in keys:
        # next level
        for c2 in element["_children"]:
            hav = hasValues(c2, level + 1)
            if hav == True:
                return True
    return False

# %%
def addChildNode(parent, elmType, element, order=1):
    pdebug(f"addChildNode parent {parent} elmType {elmType} order {order} ")
    if hasValues(element, 1):
        props = getAttributes(element)
        addChild( { "parent": parent, "children" : element["_children"], "order": order , "props": props , "elmType" : elmType })

# %%
def getScopedElement(scope, children):
    for cc in children:
        if cc["_type"] == scope:
            return cc

# %%
def processNextLevel(parent, file, element, statClassAlloc, dynClassAlloc, level, siblingCount, sibling, source):
    # we now want to gather the properties of the structure or find the references
    # We also use a default value when the property when there is no value:  'null'
    # we are only interested in the members (properties) of the structure, we don't need to create a HAS_CHILD structure now

    # when an element is a Class element (static or dynamic) we have to go to the next level to get the Members (properties)
    # we taken only the Class element name as a prefix for a member?

    elmType = element["_type"]
    keysList = getKeys(element)
    # this will be a list of childs

    if isDebug == True:
        print("  ")
        print(f"================= ProcessNextLevel ============={level} ===={elmType}")
        print( f"statClassAlloc: {statClassAlloc}" )
        print( f"dynClassAlloc: {dynClassAlloc}" )
        print(f"elmType {elmType} level {level} ")
        print( f"keysList: {keysList}" )

    isDynamicClass = elmType in file["dynamicClasses"]
    isMember = elmType in file["members"]
    isStaticClass = elmType in file["staticClasses"]
    pdebug(f" processNextLevel2: \n siblingCount/sibling={siblingCount}/{sibling} \nelmType={elmType} \nisStaticClass={isStaticClass} \nisDynamicClass={isDynamicClass} \nisMember={isMember} ")

    #
    # Rule 1 If the current element is not a member just go to the next level
    #
    #
    # Rule 2 If the current element is a Member get the properties or the relationship
    #
    if isMember == True:
        # handle Member
        handleMember(parent, element, source)
    else:
        # this is a class go a level deeper
        siblingc = 0
        if "_children" in keysList:
            for child in element["_children"]:
                siblingc = siblingc + 1
                processNextLevel(parent, file, child, statClassAlloc, dynClassAlloc, level + 1, len(element["_children"]),siblingc, source )
        else:
            handleMember(parent, element, source)

# %%
def getRef(aRef):
    # when there is an xpointer then we have to extract the oid differently
    if aRef.find("xpointer") > -1:
        # xpointer found
        splOne = aRef.split("#")
        splTwo = splOne[1].split("'")
        return splOne[0] + "#" + splTwo[1]
    return aRef

# %%
def handleMemberLevel(parent, children, source, path=""):
    pinfo(f" handleMemberLevel path {path}")
    for inst in children:
        pinfo(f" ref element {inst}")
        instKeys = getKeys(inst)
        instType = inst["_type"]
        thepath = path + "." + instType
        if "xlink:href" in instKeys:
            ref = source + "_" + getRef(inst["xlink:href"])
            index = -1
            if "index" in getKeys(inst):
                index = int(inst["index"])
            rel_type = "HAS_" + instType.upper()
            relProps = {}
            relProps["xmlpath"] = thepath
            relProps["index"] = index
            addOtherRel({"loc": "handleMemberLevel " + path, "parent": parent, "elm": instType, "ref" : ref, "rel_type": rel_type, "relProps": relProps })
        elif "_children" in instKeys:
            handleMemberLevel(parent,inst["_children"], source, thepath)
        elif "_text" in instKeys:
            # there is a value
            props = getAttributes(inst)
            props[thepath] = inst["_text"]
            addNodeProps(parent, props)
        else:
            # no value?
            addEmptyProp(parent,thepath)
            if useNoValueString == True:
                props = getAttributes(inst)
                props[thepath] = noValueString
                addNodeProps(parent, props)

# %%
def handleMember(parent, element, source):
    # with the use of static standard classes more then one property can be
    # generated
    # example <xsc:BS_Float_unit origin="0" timestamp="2013-03-25T14:00:17Z" unit="V" group="voltage">+0</xsc:BS_Float_unit>
    # the properties unit and group will be added as an extra property
    # elm + '_' + unit : value
    props = {}
    elementKeys = getKeys(element)
    elm = element["_type"]
    # we now determine what kind of member this is
    # when there are no _children and no _text
    # we skip this member
    if "_children" not in elementKeys and "_text" not in elementKeys:
        if "UID" in elementKeys:
            props = getAttributes(element)
            addNodeProps(parent, props)

        else:
            pdebug(f"handleMember no children or value for {elm} ")
            # add a null here...
            addEmptyProp(parent,elm)
            if useNoValueString == True:
                props = getAttributes(elm)
                props[elm] = noValueString
                addNodeProps(parent, props)
        return
    #
    # it there is a text value then this will be added to the parent
    #
    if "_text" in elementKeys:
        # there is a value, we take the element name as property _text as value
        # when there are aditional attibute value these will also be added TODO
        pdebug(f" value found for {element}")
        props = getAttributes(element)
        props[elm] = element["_text"]
        addNodeProps(parent, props)
        return

    #
    # Now we have children elements
    # there can be two scenarios (where we are interested in)
    # role="successor"
    # Question: there are more roles than successor and predecessor that has a xlink:href, what to do with them?
    if "role" in elementKeys:
        if element["role"] == "successor":
            # bingo a successor role possibly a relationship IS_SUCCESSOR can be created to the xlink:href referenced class
            for inst in element["_children"]:
                pdebug(f" ref element {inst}")
                ref = source + "_" + inst["xlink:href"]
                index = int(inst["index"])
                relProps = {}
                relProps["element"] = inst["_type"]
                relProps["parentElement"]= element["_type"]
                addSuccessorRel({ "parent": parent, "elm": elm, "index" : index, "ref" : ref, "relProps" : relProps})
            return
        if element["role"] != "predecessor":
            # bingo an "other" role possibly a relationship HAS_PARENTELEM can be created to the xlink:href referenced class
            handleMemberLevel(parent, element["_children"], source, element["_type"])
            return
        if element["role"] == "predecessor":
            # Skip because role=predecessor
            pinfo(f" this role (predecessor) is skipped {element['role']}")
            return
        pinfo(f" this role is needs attention XXX {element['role']}")
            #addEmptyProp(parent,elm)
            #if useNoValueString == True:
            #    props = getAttributes(elm)
            #    props[elm] = noValueString
            #    addNodeProps(parent, props)
    #
    # Handle now the scoped elementKeys, rel_name is connected to the scope
    if "scope" in elementKeys:
        scope = element["scope"]
        # get the scoped element local or remote
        scopedElement = getScopedElement(scope, element["_children"])
        # check now if there is a value
        valueElement = scopedElement["_children"][0]
        objectType = valueElement["_type"]
        pdebug(f" scopedElement {scopedElement} ")
        pdebug(f" valueElement {valueElement} \n objectType {objectType} ")
        if "_text" in getKeys(valueElement):
            memberValue = valueElement["_text"]
            valueKeys = getKeys(valueElement)
            pdebug(f" memberValue {memberValue} ")
            if objectType == "BS_Float_unit":
                props[elm] = float(memberValue)
                if "unit" in valueKeys:
                    props[elm + "_unit"] = valueElement["unit"]
                if "group" in valueKeys:
                    props[elm + "_group"] = valueElement["group"]
            elif objectType == "BS_Int32_unit":
                props[elm] = int(memberValue)
                if "unit" in valueKeys:
                    props[elm + "_unit"] = valueElement["unit"]
                if "group" in valueKeys:
                    props[elm + "_group"] = valueElement["group"]
            else:
                props[elm] = memberValue

            addNodeProps(parent, props)
            return
        if "rel_name" in getKeys(scopedElement):
            if objectType == "BS_Instance" and "xlink:href" in getKeys(valueElement):
                # there is a HAS_INSTANCE_RELATION to another object
                # the attibutes of the parent element (remote) will be on the relationship
                # for instance: rel_name="CS_Loop_CS_Key" dest_attr="CS_loop_id"
                ref = source + "_" + valueElement["xlink:href"]
                rel_type = "HAS_" + objectType.upper()
                relProps = {}
                relProps["element"] = objectType
                relProps["parentElement"]= element["_type"]
                relProps["rel_name"]= scopedElement["rel_name"]
                relProps["dest_attr"]= scopedElement["dest_attr"]
                addInstanceRel({ "parent": parent, "elm": elm, "relProps" : relProps , "ref" : ref, "rel_type": rel_type })
                return
            pinfo(f" this member {element} situation needs attention AAA")
            return
        # this is a scoped element local without a value
        # we have to create a property for this
        # pinfo(f" this scoped member {element} situation needs attention BBB ")
        addEmptyProp(parent,elm)
        if useNoValueString == True:
            props[element["_type"]] = noValueString
            addNodeProps(parent, props)
        return
    # hantera dessa på ett speciellt sätt efter lunchen!!!!!
    # check
    # there are children
    # walk through it no
    # this can be nested
    handleMemberLevel(parent, element["_children"], source, element["_type"])
    return

# %%
def processLevelElement(parentNodeId):
    tStart = time.perf_counter_ns()
    query="""
    MATCH (x)<-[:HAS_CHILD*0..]-(alloc:Allocation)<-[HAS_ALLOCATION]-(file:File)<-[:HAS_FILE]-(db:Database)
    WHERE elementId(x) = $nid
    WITH x , file, alloc
    ,     apoc.convert.getJsonProperty(x,'_children','') as children 
    ,     alloc.statClass as statClassAlloc
    ,     alloc.dynClass as dynClassAlloc
    ,     db.name as storage_interop_services_source
    ,     alloc.oid as allocationOid
    WITH elementId(x) as parent, file, children, statClassAlloc, dynClassAlloc, allocationOid, storage_interop_services_source
    return parent, children, properties(file) as file, statClassAlloc, dynClassAlloc, allocationOid, storage_interop_services_source
    """
    # this query will return one record for now
    record = session.run(query, { "nid" : parentNodeId }).single()
    parent = record["parent"]
    file = record["file"]
    statClassAlloc = record["statClassAlloc"]
    dynClassAlloc = record["dynClassAlloc"]
    recordchildren = record["children"]
    allocationOid = record["allocationOid"]
    elementCount = len(recordchildren)
    source = record["storage_interop_services_source"]
    pinfo(f"node {parent} on allocation oid={allocationOid} from sigraph file {file['name']} START. ")
    classLabel = "Classlabel"
    if dynClassAlloc != "":
        classLabel = dynClassAlloc
    else:
        classLabel = statClassAlloc

    addNodeLabel(parentNodeId, classLabel)


    #
    #
    # Processing the staticClasses
    #  processNextLevel(parent, file, element, elmType, statClassAlloc, dynClassAlloc):
    # -- If The current _type is the statClass this is then the parent of the dynClass
    pdebug(f" children count {elementCount}")
    sibling = 0
    for child in recordchildren:
        sibling = sibling + 1
        processNextLevel(parent, file, child, statClassAlloc, dynClassAlloc, 1, elementCount, sibling, source)



    duration = (time.perf_counter_ns() - tStart) // 1000000
    pinfo(f"node {parent} on allocation oid={allocationOid} from sigraph file {file['name']} in {duration} ms. ")

# %%
def processElements():
    # processing until it is done
    query = """
        MATCH (n:PrcElement) return collect(distinct elementId(n)) as ids
    """
    ids = session.run(query).single()["ids"]
    if len(ids) > 0:
        for id in ids:
            pdebug(f" calling now processLevelElement({id})")
            processLevelElement(id)
        writeToNeo4j(ids)
        processElements()
    return len(ids)

# %%
def processAllocations():
    filecount = 0
    tAllStart = time.perf_counter_ns()
    for xdir in dbDirNames:
        xmldirpath = sourceDir + xdir
        sourcename = get_file_name(xdir)
        for entry in sorted(os.listdir(xmldirpath)):
            if os.path.isfile(os.path.join(xmldirpath, entry)):
                tStart = time.perf_counter_ns()
                xmlfile = os.path.join(xmldirpath, entry)
                if xmlfile.endswith(fileFilter):
                    filecount = filecount + 1
                    saveTopStructure(xmlfile, sourcename, session)
                    processElements()
                    # clear_empty_nodes()
                    # clear_elements()
                    duration = (time.perf_counter_ns() - tStart) // 1000000
                    print(f"processed file {sourcename}/{entry} in {duration} ms")
                    #if filecount == 1:
                    #    break

    allduration = (time.perf_counter_ns() - tAllStart) // 1000000
    return "processed " + str(filecount) + " files in " + str(allduration//1000) + "s"

# %%
processingmessage = processAllocations()
# Out:
# processed file R_2016R3/data_2153.xml.gz in 15731 ms
# processed file R_2016R3/data_2154.xml.gz in 6148 ms
# processed file R_2016R3/data_2155.xml.gz in 6044 ms
# processed file R_2016R3/data_2156.xml.gz in 6701 ms
# processed file R_2016R3/data_2157.xml.gz in 5680 ms
# processed file R_2016R3/data_2158.xml.gz in 5683 ms
# processed file R_2016R3/data_2159.xml.gz in 6470 ms
# processed file R_2016R3/data_216.xml.gz in 5807 ms
# processed file R_2016R3/data_2160.xml.gz in 5019 ms
# processed file R_2016R3/data_2161.xml.gz in 7797 ms
# processed file R_2016R3/data_2162.xml.gz in 6427 ms
# processed file R_2016R3/data_2163.xml.gz in 6915 ms
# processed file R_2016R3/data_2164.xml.gz in 6707 ms
# processed file R_2016R3/data_2165.xml.gz in 7299 ms
# processed file R_2016R3/data_2166.xml.gz in 7129 ms
# processed file R_2016R3/data_2167.xml.gz in 7318 ms
# processed file R_2016R3/data_2168.xml.gz in 6852 ms
# processed file R_2016R3/data_2169.xml.gz in 5220 ms
# processed file R_2016R3/data_217.xml.gz in 7410 ms
# processed file R_2016R3/data_2170.xml.gz in 6948 ms
# processed file R_2016R3/data_2171.xml.gz in 7012 ms
# processed file R_2016R3/data_2172.xml.gz in 7318 ms
# processed file R_2016R3/data_2173.xml.gz in 6977 ms
# processed file R_2016R3/data_2174.xml.gz in 6982 ms
# processed file R_2016R3/data_2175.xml.gz in 6739 ms
# processed file R_2016R3/data_2176.xml.gz in 6817 ms
# processed file R_2016R3/data_2177.xml.gz in 7236 ms
# processed file R_2016R3/data_2178.xml.gz in 6433 ms
# processed file R_2016R3/data_2179.xml.gz in 6428 ms
# processed file R_2016R3/data_218.xml.gz in 7812 ms
# processed file R_2016R3/data_2180.xml.gz in 7104 ms
# processed file R_2016R3/data_2181.xml.gz in 7159 ms
# processed file R_2016R3/data_2182.xml.gz in 7407 ms
# processed file R_2016R3/data_2183.xml.gz in 6782 ms
# processed file R_2016R3/data_2184.xml.gz in 6709 ms
# processed file R_2016R3/data_2185.xml.gz in 7281 ms
# processed file R_2016R3/data_2186.xml.gz in 7302 ms
# processed file R_2016R3/data_2187.xml.gz in 7409 ms
# processed file R_2016R3/data_2188.xml.gz in 7218 ms
# processed file R_2016R3/data_2189.xml.gz in 7096 ms
# processed file R_2016R3/data_219.xml.gz in 7121 ms
# processed file R_2016R3/data_2190.xml.gz in 7633 ms
# processed file R_2016R3/data_2191.xml.gz in 7101 ms
# processed file R_2016R3/data_2192.xml.gz in 7330 ms
# processed file R_2016R3/data_2193.xml.gz in 7034 ms
# processed file R_2016R3/data_2194.xml.gz in 7276 ms
# processed file R_2016R3/data_2195.xml.gz in 7777 ms
# processed file R_2016R3/data_2196.xml.gz in 7667 ms
# processed file R_2016R3/data_2197.xml.gz in 7340 ms
# processed file R_2016R3/data_2198.xml.gz in 7137 ms
# processed file R_2016R3/data_2199.xml.gz in 6788 ms
# processed file R_2016R3/data_22.xml.gz in 6502 ms
# processed file R_2016R3/data_220.xml.gz in 6850 ms
# processed file R_2016R3/data_2200.xml.gz in 7645 ms
# processed file R_2016R3/data_2201.xml.gz in 7462 ms
# processed file R_2016R3/data_2202.xml.gz in 7916 ms
# processed file R_2016R3/data_2203.xml.gz in 7434 ms
# processed file R_2016R3/data_2204.xml.gz in 7532 ms
# processed file R_2016R3/data_2205.xml.gz in 7191 ms
# processed file R_2016R3/data_2206.xml.gz in 6456 ms
# processed file R_2016R3/data_2207.xml.gz in 6715 ms
# processed file R_2016R3/data_2208.xml.gz in 7239 ms
# processed file R_2016R3/data_2209.xml.gz in 7246 ms
# processed file R_2016R3/data_221.xml.gz in 7944 ms
# processed file R_2016R3/data_2210.xml.gz in 6897 ms
# processed file R_2016R3/data_2211.xml.gz in 7473 ms
# processed file R_2016R3/data_2212.xml.gz in 7379 ms
# processed file R_2016R3/data_2213.xml.gz in 7236 ms
# processed file R_2016R3/data_2214.xml.gz in 6793 ms
# processed file R_2016R3/data_2215.xml.gz in 7939 ms
# processed file R_2016R3/data_2216.xml.gz in 7773 ms
# processed file R_2016R3/data_2217.xml.gz in 7549 ms
# processed file R_2016R3/data_2218.xml.gz in 7277 ms
# processed file R_2016R3/data_2219.xml.gz in 7354 ms
# processed file R_2016R3/data_222.xml.gz in 7690 ms
# processed file R_2016R3/data_2220.xml.gz in 7330 ms
# processed file R_2016R3/data_2221.xml.gz in 6664 ms
# processed file R_2016R3/data_2222.xml.gz in 7525 ms
# processed file R_2016R3/data_2223.xml.gz in 7263 ms
# processed file R_2016R3/data_2224.xml.gz in 6971 ms
# processed file R_2016R3/data_2225.xml.gz in 7078 ms
# processed file R_2016R3/data_2226.xml.gz in 6851 ms
# processed file R_2016R3/data_2227.xml.gz in 7226 ms
# processed file R_2016R3/data_2228.xml.gz in 7319 ms
# processed file R_2016R3/data_2229.xml.gz in 7163 ms
# processed file R_2016R3/data_223.xml.gz in 8186 ms
# processed file R_2016R3/data_2230.xml.gz in 7197 ms
# processed file R_2016R3/data_2231.xml.gz in 7113 ms
# processed file R_2016R3/data_2232.xml.gz in 6815 ms
# processed file R_2016R3/data_2233.xml.gz in 7345 ms
# processed file R_2016R3/data_2234.xml.gz in 7106 ms
# processed file R_2016R3/data_2235.xml.gz in 7939 ms
# processed file R_2016R3/data_2236.xml.gz in 7355 ms
# processed file R_2016R3/data_2237.xml.gz in 7367 ms
# processed file R_2016R3/data_2238.xml.gz in 7597 ms
# processed file R_2016R3/data_2239.xml.gz in 7701 ms
# processed file R_2016R3/data_224.xml.gz in 7936 ms
# processed file R_2016R3/data_2240.xml.gz in 7195 ms
# processed file R_2016R3/data_2241.xml.gz in 7518 ms
# processed file R_2016R3/data_2242.xml.gz in 7672 ms
# processed file R_2016R3/data_2243.xml.gz in 7262 ms
# processed file R_2016R3/data_2244.xml.gz in 7833 ms
# processed file R_2016R3/data_2245.xml.gz in 7869 ms
# processed file R_2016R3/data_2246.xml.gz in 7896 ms
# processed file R_2016R3/data_2247.xml.gz in 7261 ms
# processed file R_2016R3/data_2248.xml.gz in 7820 ms
# processed file R_2016R3/data_2249.xml.gz in 7519 ms
# processed file R_2016R3/data_225.xml.gz in 7868 ms
# processed file R_2016R3/data_2250.xml.gz in 7236 ms
# processed file R_2016R3/data_2251.xml.gz in 6767 ms
# processed file R_2016R3/data_2252.xml.gz in 6816 ms
# processed file R_2016R3/data_2253.xml.gz in 6967 ms
# processed file R_2016R3/data_2254.xml.gz in 7436 ms
# processed file R_2016R3/data_2255.xml.gz in 7042 ms
# processed file R_2016R3/data_2256.xml.gz in 7795 ms
# processed file R_2016R3/data_2257.xml.gz in 8087 ms
# processed file R_2016R3/data_2258.xml.gz in 6798 ms
# processed file R_2016R3/data_2259.xml.gz in 7030 ms
# processed file R_2016R3/data_226.xml.gz in 7205 ms
# processed file R_2016R3/data_2260.xml.gz in 7076 ms
# processed file R_2016R3/data_2261.xml.gz in 7273 ms
# processed file R_2016R3/data_2262.xml.gz in 7658 ms
# processed file R_2016R3/data_2263.xml.gz in 7641 ms
# processed file R_2016R3/data_2264.xml.gz in 8591 ms
# processed file R_2016R3/data_2265.xml.gz in 6703 ms
# processed file R_2016R3/data_2266.xml.gz in 6744 ms
# processed file R_2016R3/data_2267.xml.gz in 7274 ms
# processed file R_2016R3/data_2268.xml.gz in 7874 ms
# processed file R_2016R3/data_2269.xml.gz in 7020 ms
# processed file R_2016R3/data_227.xml.gz in 7116 ms
# processed file R_2016R3/data_2270.xml.gz in 7976 ms
# processed file R_2016R3/data_2271.xml.gz in 7374 ms
# processed file R_2016R3/data_2272.xml.gz in 6825 ms
# processed file R_2016R3/data_2273.xml.gz in 8140 ms
# processed file R_2016R3/data_2274.xml.gz in 6869 ms
# processed file R_2016R3/data_2275.xml.gz in 6939 ms
# processed file R_2016R3/data_2276.xml.gz in 6581 ms
# processed file R_2016R3/data_2277.xml.gz in 6869 ms
# processed file R_2016R3/data_2278.xml.gz in 6653 ms
# processed file R_2016R3/data_2279.xml.gz in 6687 ms
# processed file R_2016R3/data_228.xml.gz in 8107 ms
# processed file R_2016R3/data_2280.xml.gz in 6804 ms
# processed file R_2016R3/data_2281.xml.gz in 6803 ms
# processed file R_2016R3/data_2282.xml.gz in 7119 ms
# processed file R_2016R3/data_2283.xml.gz in 6128 ms
# processed file R_2016R3/data_2284.xml.gz in 6725 ms
# processed file R_2016R3/data_2285.xml.gz in 6385 ms
# processed file R_2016R3/data_2286.xml.gz in 6788 ms
# processed file R_2016R3/data_2287.xml.gz in 6382 ms
# processed file R_2016R3/data_2288.xml.gz in 7341 ms
# processed file R_2016R3/data_2289.xml.gz in 7284 ms
# processed file R_2016R3/data_229.xml.gz in 7274 ms
# processed file R_2016R3/data_2290.xml.gz in 6303 ms
# processed file R_2016R3/data_2291.xml.gz in 5980 ms
# processed file R_2016R3/data_2292.xml.gz in 6790 ms
# processed file R_2016R3/data_2293.xml.gz in 7719 ms
# processed file R_2016R3/data_2294.xml.gz in 7320 ms
# processed file R_2016R3/data_2295.xml.gz in 7652 ms
# processed file R_2016R3/data_2296.xml.gz in 7476 ms
# processed file R_2016R3/data_2297.xml.gz in 7553 ms
# processed file R_2016R3/data_2298.xml.gz in 7285 ms
# processed file R_2016R3/data_2299.xml.gz in 7932 ms
# processed file R_2016R3/data_23.xml.gz in 6522 ms
# processed file R_2016R3/data_230.xml.gz in 7282 ms
# processed file R_2016R3/data_2300.xml.gz in 7817 ms
# processed file R_2016R3/data_2301.xml.gz in 7589 ms
# processed file R_2016R3/data_2302.xml.gz in 7358 ms
# processed file R_2016R3/data_2303.xml.gz in 7885 ms
# processed file R_2016R3/data_2304.xml.gz in 7020 ms
# processed file R_2016R3/data_2305.xml.gz in 7332 ms
# processed file R_2016R3/data_2306.xml.gz in 7175 ms
# processed file R_2016R3/data_2307.xml.gz in 7845 ms
# processed file R_2016R3/data_2308.xml.gz in 7150 ms
# processed file R_2016R3/data_2309.xml.gz in 7471 ms
# processed file R_2016R3/data_231.xml.gz in 7230 ms
# processed file R_2016R3/data_2310.xml.gz in 8023 ms
# processed file R_2016R3/data_2311.xml.gz in 7885 ms
# processed file R_2016R3/data_2312.xml.gz in 7609 ms
# processed file R_2016R3/data_2313.xml.gz in 7574 ms
# processed file R_2016R3/data_2314.xml.gz in 8744 ms
# processed file R_2016R3/data_2315.xml.gz in 7177 ms
# processed file R_2016R3/data_2316.xml.gz in 7454 ms
# processed file R_2016R3/data_2317.xml.gz in 8030 ms
# processed file R_2016R3/data_2318.xml.gz in 7933 ms
# processed file R_2016R3/data_2319.xml.gz in 7387 ms
# processed file R_2016R3/data_232.xml.gz in 7130 ms
# processed file R_2016R3/data_2320.xml.gz in 7339 ms
# processed file R_2016R3/data_2321.xml.gz in 7713 ms
# processed file R_2016R3/data_2322.xml.gz in 7913 ms
# processed file R_2016R3/data_2323.xml.gz in 7534 ms
# processed file R_2016R3/data_2324.xml.gz in 7308 ms
# processed file R_2016R3/data_2325.xml.gz in 8456 ms
# processed file R_2016R3/data_2326.xml.gz in 7983 ms
# processed file R_2016R3/data_2327.xml.gz in 7717 ms
# processed file R_2016R3/data_2328.xml.gz in 7636 ms
# processed file R_2016R3/data_2329.xml.gz in 7981 ms
# processed file R_2016R3/data_233.xml.gz in 7744 ms
# processed file R_2016R3/data_2330.xml.gz in 7650 ms
# processed file R_2016R3/data_2331.xml.gz in 7535 ms
# processed file R_2016R3/data_2332.xml.gz in 7787 ms
# processed file R_2016R3/data_2333.xml.gz in 8224 ms
# processed file R_2016R3/data_2334.xml.gz in 7940 ms
# processed file R_2016R3/data_2335.xml.gz in 7522 ms
# processed file R_2016R3/data_2336.xml.gz in 7414 ms
# processed file R_2016R3/data_2337.xml.gz in 8737 ms
# processed file R_2016R3/data_2338.xml.gz in 7473 ms
# processed file R_2016R3/data_2339.xml.gz in 7435 ms
# processed file R_2016R3/data_234.xml.gz in 7333 ms
# processed file R_2016R3/data_2340.xml.gz in 7969 ms
# processed file R_2016R3/data_2341.xml.gz in 8632 ms
# processed file R_2016R3/data_2342.xml.gz in 7318 ms
# processed file R_2016R3/data_2343.xml.gz in 7370 ms
# processed file R_2016R3/data_2344.xml.gz in 7558 ms
# processed file R_2016R3/data_2345.xml.gz in 8320 ms
# processed file R_2016R3/data_2346.xml.gz in 6981 ms
# processed file R_2016R3/data_2347.xml.gz in 7126 ms
# processed file R_2016R3/data_2348.xml.gz in 7994 ms
# processed file R_2016R3/data_2349.xml.gz in 8005 ms
# processed file R_2016R3/data_235.xml.gz in 7924 ms
# processed file R_2016R3/data_2350.xml.gz in 7548 ms
# processed file R_2016R3/data_2351.xml.gz in 7853 ms
# processed file R_2016R3/data_2352.xml.gz in 7669 ms
# processed file R_2016R3/data_2353.xml.gz in 8290 ms
# processed file R_2016R3/data_2354.xml.gz in 7542 ms
# processed file R_2016R3/data_2355.xml.gz in 7231 ms
# processed file R_2016R3/data_2356.xml.gz in 7580 ms
# processed file R_2016R3/data_2357.xml.gz in 8308 ms
# processed file R_2016R3/data_2358.xml.gz in 7593 ms
# processed file R_2016R3/data_2359.xml.gz in 7748 ms
# processed file R_2016R3/data_236.xml.gz in 7722 ms
# processed file R_2016R3/data_2360.xml.gz in 7758 ms
# processed file R_2016R3/data_2361.xml.gz in 7421 ms
# processed file R_2016R3/data_2362.xml.gz in 7551 ms
# processed file R_2016R3/data_2363.xml.gz in 8534 ms
# processed file R_2016R3/data_2364.xml.gz in 7345 ms
# processed file R_2016R3/data_2365.xml.gz in 7586 ms
# processed file R_2016R3/data_2366.xml.gz in 8469 ms
# processed file R_2016R3/data_2367.xml.gz in 7459 ms
# processed file R_2016R3/data_2368.xml.gz in 7485 ms
# processed file R_2016R3/data_2369.xml.gz in 7967 ms
# processed file R_2016R3/data_237.xml.gz in 7257 ms
# processed file R_2016R3/data_2370.xml.gz in 7807 ms
# processed file R_2016R3/data_2371.xml.gz in 7332 ms
# processed file R_2016R3/data_2372.xml.gz in 7894 ms
# processed file R_2016R3/data_2373.xml.gz in 7525 ms
# processed file R_2016R3/data_2374.xml.gz in 7574 ms
# processed file R_2016R3/data_2375.xml.gz in 7527 ms
# processed file R_2016R3/data_2376.xml.gz in 8554 ms
# processed file R_2016R3/data_2377.xml.gz in 7138 ms
# processed file R_2016R3/data_2378.xml.gz in 7565 ms
# processed file R_2016R3/data_2379.xml.gz in 7263 ms
# processed file R_2016R3/data_238.xml.gz in 8071 ms
# processed file R_2016R3/data_2380.xml.gz in 8438 ms
# processed file R_2016R3/data_2381.xml.gz in 7167 ms
# processed file R_2016R3/data_2382.xml.gz in 7886 ms
# processed file R_2016R3/data_2383.xml.gz in 8413 ms
# processed file R_2016R3/data_2384.xml.gz in 7138 ms
# processed file R_2016R3/data_2385.xml.gz in 7464 ms
# processed file R_2016R3/data_2386.xml.gz in 8258 ms
# processed file R_2016R3/data_2387.xml.gz in 8241 ms
# processed file R_2016R3/data_2388.xml.gz in 7417 ms
# processed file R_2016R3/data_2389.xml.gz in 7519 ms
# processed file R_2016R3/data_239.xml.gz in 6956 ms
# processed file R_2016R3/data_2390.xml.gz in 8186 ms
# processed file R_2016R3/data_2391.xml.gz in 7757 ms
# processed file R_2016R3/data_2392.xml.gz in 7186 ms
# processed file R_2016R3/data_2393.xml.gz in 7921 ms
# processed file R_2016R3/data_2394.xml.gz in 7328 ms
# processed file R_2016R3/data_2395.xml.gz in 7459 ms
# processed file R_2016R3/data_2396.xml.gz in 7516 ms
# processed file R_2016R3/data_2397.xml.gz in 8492 ms
# processed file R_2016R3/data_2398.xml.gz in 7514 ms
# processed file R_2016R3/data_2399.xml.gz in 7607 ms
# processed file R_2016R3/data_24.xml.gz in 7163 ms
# processed file R_2016R3/data_240.xml.gz in 7232 ms
# processed file R_2016R3/data_2400.xml.gz in 7544 ms
# processed file R_2016R3/data_2401.xml.gz in 7546 ms
# processed file R_2016R3/data_2402.xml.gz in 7423 ms
# processed file R_2016R3/data_2403.xml.gz in 7946 ms
# processed file R_2016R3/data_2404.xml.gz in 7109 ms
# processed file R_2016R3/data_2405.xml.gz in 7069 ms
# processed file R_2016R3/data_2406.xml.gz in 7092 ms
# processed file R_2016R3/data_2407.xml.gz in 7239 ms
# processed file R_2016R3/data_2408.xml.gz in 7547 ms
# processed file R_2016R3/data_2409.xml.gz in 7515 ms
# processed file R_2016R3/data_241.xml.gz in 7631 ms
# processed file R_2016R3/data_2410.xml.gz in 7650 ms
# processed file R_2016R3/data_2411.xml.gz in 7163 ms
# processed file R_2016R3/data_2412.xml.gz in 7318 ms
# processed file R_2016R3/data_2413.xml.gz in 7215 ms
# processed file R_2016R3/data_2414.xml.gz in 7793 ms
# processed file R_2016R3/data_2415.xml.gz in 7219 ms
# processed file R_2016R3/data_2416.xml.gz in 7876 ms
# processed file R_2016R3/data_2417.xml.gz in 7142 ms
# processed file R_2016R3/data_2418.xml.gz in 7475 ms
# processed file R_2016R3/data_2419.xml.gz in 7616 ms
# processed file R_2016R3/data_242.xml.gz in 7500 ms
# processed file R_2016R3/data_2420.xml.gz in 7141 ms
# processed file R_2016R3/data_2421.xml.gz in 7858 ms
# processed file R_2016R3/data_2422.xml.gz in 7229 ms
# processed file R_2016R3/data_2423.xml.gz in 7445 ms
# processed file R_2016R3/data_2424.xml.gz in 7778 ms
# processed file R_2016R3/data_2425.xml.gz in 7273 ms
# processed file R_2016R3/data_2426.xml.gz in 7281 ms
# processed file R_2016R3/data_2427.xml.gz in 7990 ms
# processed file R_2016R3/data_2428.xml.gz in 7844 ms
# processed file R_2016R3/data_2429.xml.gz in 7099 ms
# processed file R_2016R3/data_243.xml.gz in 7335 ms
# processed file R_2016R3/data_2430.xml.gz in 7870 ms
# processed file R_2016R3/data_2431.xml.gz in 7922 ms
# processed file R_2016R3/data_2432.xml.gz in 8190 ms
# processed file R_2016R3/data_2433.xml.gz in 7535 ms
# processed file R_2016R3/data_2434.xml.gz in 7932 ms
# processed file R_2016R3/data_2435.xml.gz in 8063 ms
# processed file R_2016R3/data_2436.xml.gz in 7565 ms
# processed file R_2016R3/data_2437.xml.gz in 7664 ms
# processed file R_2016R3/data_2438.xml.gz in 7786 ms
# processed file R_2016R3/data_2439.xml.gz in 7405 ms
# processed file R_2016R3/data_244.xml.gz in 7698 ms
# processed file R_2016R3/data_2440.xml.gz in 7544 ms
# processed file R_2016R3/data_2441.xml.gz in 7627 ms
# processed file R_2016R3/data_2442.xml.gz in 8050 ms
# processed file R_2016R3/data_2443.xml.gz in 7856 ms
# processed file R_2016R3/data_2444.xml.gz in 7047 ms
# processed file R_2016R3/data_2445.xml.gz in 7841 ms
# processed file R_2016R3/data_2446.xml.gz in 7701 ms
# processed file R_2016R3/data_2447.xml.gz in 7389 ms
# processed file R_2016R3/data_2448.xml.gz in 7536 ms
# processed file R_2016R3/data_2449.xml.gz in 7752 ms
# processed file R_2016R3/data_245.xml.gz in 7680 ms
# processed file R_2016R3/data_2450.xml.gz in 7429 ms
# processed file R_2016R3/data_2451.xml.gz in 7468 ms
# processed file R_2016R3/data_2452.xml.gz in 8150 ms
# processed file R_2016R3/data_2453.xml.gz in 8198 ms
# processed file R_2016R3/data_2454.xml.gz in 7451 ms
# processed file R_2016R3/data_2455.xml.gz in 7537 ms
# processed file R_2016R3/data_2456.xml.gz in 8041 ms
# processed file R_2016R3/data_2457.xml.gz in 7989 ms
# processed file R_2016R3/data_2458.xml.gz in 7368 ms
# processed file R_2016R3/data_2459.xml.gz in 7386 ms
# processed file R_2016R3/data_246.xml.gz in 7115 ms
# processed file R_2016R3/data_2460.xml.gz in 8490 ms
# processed file R_2016R3/data_2461.xml.gz in 7177 ms
# processed file R_2016R3/data_2462.xml.gz in 7531 ms
# processed file R_2016R3/data_2463.xml.gz in 8025 ms
# processed file R_2016R3/data_2464.xml.gz in 8204 ms
# processed file R_2016R3/data_2465.xml.gz in 7156 ms
# processed file R_2016R3/data_2466.xml.gz in 7848 ms
# processed file R_2016R3/data_2467.xml.gz in 7478 ms
# processed file R_2016R3/data_2468.xml.gz in 7911 ms
# processed file R_2016R3/data_2469.xml.gz in 7272 ms
# processed file R_2016R3/data_247.xml.gz in 7303 ms
# processed file R_2016R3/data_2470.xml.gz in 7758 ms
# processed file R_2016R3/data_2471.xml.gz in 8353 ms
# processed file R_2016R3/data_2472.xml.gz in 7362 ms
# processed file R_2016R3/data_2473.xml.gz in 7769 ms
# processed file R_2016R3/data_2474.xml.gz in 7826 ms
# processed file R_2016R3/data_2475.xml.gz in 7642 ms
# processed file R_2016R3/data_2476.xml.gz in 7517 ms
# processed file R_2016R3/data_2477.xml.gz in 7703 ms
# processed file R_2016R3/data_2478.xml.gz in 7638 ms
# processed file R_2016R3/data_2479.xml.gz in 7335 ms
# processed file R_2016R3/data_248.xml.gz in 7628 ms
# processed file R_2016R3/data_2480.xml.gz in 7782 ms
# processed file R_2016R3/data_2481.xml.gz in 7941 ms
# processed file R_2016R3/data_2482.xml.gz in 7461 ms
# processed file R_2016R3/data_2483.xml.gz in 7283 ms
# processed file R_2016R3/data_2484.xml.gz in 7852 ms
# processed file R_2016R3/data_2485.xml.gz in 7359 ms
# processed file R_2016R3/data_2486.xml.gz in 7606 ms
# processed file R_2016R3/data_2487.xml.gz in 7612 ms
# processed file R_2016R3/data_2488.xml.gz in 8019 ms
# processed file R_2016R3/data_2489.xml.gz in 7844 ms
# processed file R_2016R3/data_249.xml.gz in 8011 ms
# processed file R_2016R3/data_2490.xml.gz in 7691 ms
# processed file R_2016R3/data_2491.xml.gz in 7764 ms
# processed file R_2016R3/data_2492.xml.gz in 7840 ms
# processed file R_2016R3/data_2493.xml.gz in 7456 ms
# processed file R_2016R3/data_2494.xml.gz in 7906 ms
# processed file R_2016R3/data_2495.xml.gz in 7680 ms
# processed file R_2016R3/data_2496.xml.gz in 7449 ms
# processed file R_2016R3/data_2497.xml.gz in 7578 ms
# processed file R_2016R3/data_2498.xml.gz in 7746 ms
# processed file R_2016R3/data_2499.xml.gz in 8237 ms
# processed file R_2016R3/data_25.xml.gz in 6779 ms
# processed file R_2016R3/data_250.xml.gz in 7320 ms
# processed file R_2016R3/data_2500.xml.gz in 7252 ms
# processed file R_2016R3/data_2501.xml.gz in 6995 ms
# processed file R_2016R3/data_2502.xml.gz in 7797 ms
# processed file R_2016R3/data_2503.xml.gz in 7773 ms
# processed file R_2016R3/data_2504.xml.gz in 6999 ms
# processed file R_2016R3/data_2505.xml.gz in 7188 ms
# processed file R_2016R3/data_2506.xml.gz in 7611 ms
# processed file R_2016R3/data_2507.xml.gz in 7951 ms
# processed file R_2016R3/data_2508.xml.gz in 7598 ms
# processed file R_2016R3/data_2509.xml.gz in 7601 ms
# processed file R_2016R3/data_251.xml.gz in 7496 ms
# processed file R_2016R3/data_2510.xml.gz in 8618 ms
# processed file R_2016R3/data_2511.xml.gz in 6851 ms
# processed file R_2016R3/data_2512.xml.gz in 7241 ms
# processed file R_2016R3/data_2513.xml.gz in 7807 ms
# processed file R_2016R3/data_2514.xml.gz in 8347 ms
# processed file R_2016R3/data_2515.xml.gz in 7525 ms
# processed file R_2016R3/data_2516.xml.gz in 7313 ms
# processed file R_2016R3/data_2517.xml.gz in 8008 ms
# processed file R_2016R3/data_2518.xml.gz in 8123 ms
# processed file R_2016R3/data_2519.xml.gz in 7625 ms
# processed file R_2016R3/data_252.xml.gz in 8861 ms
# processed file R_2016R3/data_2520.xml.gz in 7425 ms
# processed file R_2016R3/data_2521.xml.gz in 8145 ms
# processed file R_2016R3/data_2522.xml.gz in 7237 ms
# processed file R_2016R3/data_2523.xml.gz in 7867 ms
# processed file R_2016R3/data_2524.xml.gz in 7695 ms
# processed file R_2016R3/data_2525.xml.gz in 7988 ms
# processed file R_2016R3/data_2526.xml.gz in 7421 ms
# processed file R_2016R3/data_2527.xml.gz in 7435 ms
# processed file R_2016R3/data_2528.xml.gz in 8196 ms
# processed file R_2016R3/data_2529.xml.gz in 7380 ms
# processed file R_2016R3/data_253.xml.gz in 7096 ms
# processed file R_2016R3/data_2530.xml.gz in 7628 ms
# processed file R_2016R3/data_2531.xml.gz in 7144 ms
# processed file R_2016R3/data_2532.xml.gz in 8235 ms
# processed file R_2016R3/data_2533.xml.gz in 6878 ms
# processed file R_2016R3/data_2534.xml.gz in 7087 ms
# processed file R_2016R3/data_2535.xml.gz in 7484 ms
# processed file R_2016R3/data_2536.xml.gz in 7683 ms
# processed file R_2016R3/data_2537.xml.gz in 7037 ms
# processed file R_2016R3/data_2538.xml.gz in 7532 ms
# processed file R_2016R3/data_2539.xml.gz in 7910 ms
# processed file R_2016R3/data_254.xml.gz in 7136 ms
# processed file R_2016R3/data_2540.xml.gz in 7534 ms
# processed file R_2016R3/data_2541.xml.gz in 7884 ms
# processed file R_2016R3/data_2542.xml.gz in 8078 ms
# processed file R_2016R3/data_2543.xml.gz in 7811 ms
# processed file R_2016R3/data_2544.xml.gz in 7338 ms
# processed file R_2016R3/data_2545.xml.gz in 7574 ms
# processed file R_2016R3/data_2546.xml.gz in 8678 ms
# processed file R_2016R3/data_2547.xml.gz in 7052 ms
# processed file R_2016R3/data_2548.xml.gz in 6982 ms
# processed file R_2016R3/data_2549.xml.gz in 7939 ms
# processed file R_2016R3/data_255.xml.gz in 7484 ms
# processed file R_2016R3/data_2550.xml.gz in 6851 ms
# processed file R_2016R3/data_2551.xml.gz in 7936 ms
# processed file R_2016R3/data_2552.xml.gz in 6735 ms
# processed file R_2016R3/data_2553.xml.gz in 7034 ms
# processed file R_2016R3/data_2554.xml.gz in 7896 ms
# processed file R_2016R3/data_2555.xml.gz in 6691 ms
# processed file R_2016R3/data_2556.xml.gz in 7188 ms
# processed file R_2016R3/data_2557.xml.gz in 7013 ms
# processed file R_2016R3/data_2558.xml.gz in 6466 ms
# processed file R_2016R3/data_2559.xml.gz in 6880 ms
# processed file R_2016R3/data_256.xml.gz in 7846 ms
# processed file R_2016R3/data_2560.xml.gz in 7317 ms
# processed file R_2016R3/data_2561.xml.gz in 6716 ms
# processed file R_2016R3/data_2562.xml.gz in 6546 ms
# processed file R_2016R3/data_2563.xml.gz in 6908 ms
# processed file R_2016R3/data_2564.xml.gz in 6695 ms
# processed file R_2016R3/data_2565.xml.gz in 6765 ms
# processed file R_2016R3/data_2566.xml.gz in 6762 ms
# processed file R_2016R3/data_2567.xml.gz in 6693 ms
# processed file R_2016R3/data_2568.xml.gz in 7477 ms
# processed file R_2016R3/data_2569.xml.gz in 6904 ms
# processed file R_2016R3/data_257.xml.gz in 6848 ms
# processed file R_2016R3/data_2570.xml.gz in 6963 ms
# processed file R_2016R3/data_2571.xml.gz in 6621 ms
# processed file R_2016R3/data_2572.xml.gz in 7277 ms
# processed file R_2016R3/data_2573.xml.gz in 6798 ms
# processed file R_2016R3/data_2574.xml.gz in 6887 ms
# processed file R_2016R3/data_2575.xml.gz in 7317 ms
# processed file R_2016R3/data_2576.xml.gz in 7222 ms
# processed file R_2016R3/data_2577.xml.gz in 7417 ms
# processed file R_2016R3/data_2578.xml.gz in 6630 ms
# processed file R_2016R3/data_2579.xml.gz in 7172 ms
# processed file R_2016R3/data_258.xml.gz in 6907 ms
# processed file R_2016R3/data_2580.xml.gz in 6925 ms
# processed file R_2016R3/data_2581.xml.gz in 6933 ms
# processed file R_2016R3/data_2582.xml.gz in 7012 ms
# processed file R_2016R3/data_2583.xml.gz in 6795 ms
# processed file R_2016R3/data_2584.xml.gz in 7443 ms
# processed file R_2016R3/data_2585.xml.gz in 6690 ms
# processed file R_2016R3/data_2586.xml.gz in 7168 ms
# processed file R_2016R3/data_2587.xml.gz in 7534 ms
# processed file R_2016R3/data_2588.xml.gz in 7052 ms
# processed file R_2016R3/data_2589.xml.gz in 7352 ms
# processed file R_2016R3/data_259.xml.gz in 7663 ms
# processed file R_2016R3/data_2590.xml.gz in 7168 ms
# processed file R_2016R3/data_2591.xml.gz in 7124 ms
# processed file R_2016R3/data_2592.xml.gz in 7058 ms
# processed file R_2016R3/data_2593.xml.gz in 8031 ms
# processed file R_2016R3/data_2594.xml.gz in 6768 ms
# processed file R_2016R3/data_2595.xml.gz in 6839 ms
# processed file R_2016R3/data_2596.xml.gz in 6665 ms
# processed file R_2016R3/data_2597.xml.gz in 6521 ms
# processed file R_2016R3/data_2598.xml.gz in 6913 ms
# processed file R_2016R3/data_2599.xml.gz in 7218 ms
# processed file R_2016R3/data_26.xml.gz in 6853 ms
# processed file R_2016R3/data_260.xml.gz in 7712 ms
# processed file R_2016R3/data_2600.xml.gz in 6817 ms
# processed file R_2016R3/data_2601.xml.gz in 7082 ms
# processed file R_2016R3/data_2602.xml.gz in 7227 ms
# processed file R_2016R3/data_2603.xml.gz in 7166 ms
# processed file R_2016R3/data_2604.xml.gz in 6953 ms
# processed file R_2016R3/data_2605.xml.gz in 7245 ms
# processed file R_2016R3/data_2606.xml.gz in 7093 ms
# processed file R_2016R3/data_2607.xml.gz in 7182 ms
# processed file R_2016R3/data_2608.xml.gz in 6843 ms
# processed file R_2016R3/data_2609.xml.gz in 7168 ms
# processed file R_2016R3/data_261.xml.gz in 6864 ms
# processed file R_2016R3/data_2610.xml.gz in 7207 ms
# processed file R_2016R3/data_2611.xml.gz in 7326 ms
# processed file R_2016R3/data_2612.xml.gz in 6930 ms
# processed file R_2016R3/data_2613.xml.gz in 7627 ms
# processed file R_2016R3/data_2614.xml.gz in 6883 ms
# processed file R_2016R3/data_2615.xml.gz in 6754 ms
# processed file R_2016R3/data_2616.xml.gz in 7185 ms
# processed file R_2016R3/data_2617.xml.gz in 6965 ms
# processed file R_2016R3/data_2618.xml.gz in 6969 ms
# processed file R_2016R3/data_2619.xml.gz in 7135 ms
# processed file R_2016R3/data_262.xml.gz in 7144 ms
# processed file R_2016R3/data_2620.xml.gz in 6965 ms
# processed file R_2016R3/data_2621.xml.gz in 7808 ms
# processed file R_2016R3/data_2622.xml.gz in 6426 ms
# processed file R_2016R3/data_2623.xml.gz in 6610 ms
# processed file R_2016R3/data_2624.xml.gz in 7471 ms
# processed file R_2016R3/data_2625.xml.gz in 7633 ms
# processed file R_2016R3/data_2626.xml.gz in 7214 ms
# processed file R_2016R3/data_2627.xml.gz in 7084 ms
# processed file R_2016R3/data_2628.xml.gz in 7016 ms
# processed file R_2016R3/data_2629.xml.gz in 6844 ms
# processed file R_2016R3/data_263.xml.gz in 7676 ms
# processed file R_2016R3/data_2630.xml.gz in 7221 ms
# processed file R_2016R3/data_2631.xml.gz in 7403 ms
# processed file R_2016R3/data_2632.xml.gz in 7292 ms
# processed file R_2016R3/data_2633.xml.gz in 7505 ms
# processed file R_2016R3/data_2634.xml.gz in 7383 ms
# processed file R_2016R3/data_2635.xml.gz in 7521 ms
# processed file R_2016R3/data_2636.xml.gz in 7272 ms
# processed file R_2016R3/data_2637.xml.gz in 7417 ms
# processed file R_2016R3/data_2638.xml.gz in 7523 ms
# processed file R_2016R3/data_2639.xml.gz in 8372 ms
# processed file R_2016R3/data_264.xml.gz in 7388 ms
# processed file R_2016R3/data_2640.xml.gz in 7557 ms
# processed file R_2016R3/data_2641.xml.gz in 7169 ms
# processed file R_2016R3/data_2642.xml.gz in 7575 ms
# processed file R_2016R3/data_2643.xml.gz in 7756 ms
# processed file R_2016R3/data_2644.xml.gz in 7963 ms
# processed file R_2016R3/data_2645.xml.gz in 7842 ms
# processed file R_2016R3/data_2646.xml.gz in 7216 ms
# processed file R_2016R3/data_2647.xml.gz in 7356 ms
# processed file R_2016R3/data_2648.xml.gz in 7713 ms
# processed file R_2016R3/data_2649.xml.gz in 7880 ms
# processed file R_2016R3/data_265.xml.gz in 7305 ms
# processed file R_2016R3/data_2650.xml.gz in 8047 ms
# processed file R_2016R3/data_2651.xml.gz in 7503 ms
# processed file R_2016R3/data_2652.xml.gz in 7363 ms
# processed file R_2016R3/data_2653.xml.gz in 7514 ms
# processed file R_2016R3/data_2654.xml.gz in 7710 ms
# processed file R_2016R3/data_2655.xml.gz in 8648 ms
# processed file R_2016R3/data_2656.xml.gz in 7112 ms
# processed file R_2016R3/data_2657.xml.gz in 7442 ms
# processed file R_2016R3/data_2658.xml.gz in 7983 ms
# processed file R_2016R3/data_2659.xml.gz in 7719 ms
# processed file R_2016R3/data_266.xml.gz in 7785 ms
# processed file R_2016R3/data_2660.xml.gz in 7398 ms
# processed file R_2016R3/data_2661.xml.gz in 7552 ms
# processed file R_2016R3/data_2662.xml.gz in 7418 ms
# processed file R_2016R3/data_2663.xml.gz in 7498 ms
# processed file R_2016R3/data_2664.xml.gz in 7668 ms
# processed file R_2016R3/data_2665.xml.gz in 7383 ms
# processed file R_2016R3/data_2666.xml.gz in 7549 ms
# processed file R_2016R3/data_2667.xml.gz in 7508 ms
# processed file R_2016R3/data_2668.xml.gz in 8064 ms
# processed file R_2016R3/data_2669.xml.gz in 7201 ms
# processed file R_2016R3/data_267.xml.gz in 7424 ms
# processed file R_2016R3/data_2670.xml.gz in 7290 ms
# processed file R_2016R3/data_2671.xml.gz in 7351 ms
# processed file R_2016R3/data_2672.xml.gz in 7460 ms
# processed file R_2016R3/data_2673.xml.gz in 7339 ms
# processed file R_2016R3/data_2674.xml.gz in 7459 ms
# processed file R_2016R3/data_2675.xml.gz in 7508 ms
# processed file R_2016R3/data_2676.xml.gz in 7506 ms
# processed file R_2016R3/data_2677.xml.gz in 7644 ms
# processed file R_2016R3/data_2678.xml.gz in 7627 ms
# processed file R_2016R3/data_2679.xml.gz in 7818 ms
# processed file R_2016R3/data_268.xml.gz in 7636 ms
# processed file R_2016R3/data_2680.xml.gz in 7399 ms
# processed file R_2016R3/data_2681.xml.gz in 7527 ms
# processed file R_2016R3/data_2682.xml.gz in 7719 ms
# processed file R_2016R3/data_2683.xml.gz in 8108 ms
# processed file R_2016R3/data_2684.xml.gz in 7454 ms
# processed file R_2016R3/data_2685.xml.gz in 7534 ms
# processed file R_2016R3/data_2686.xml.gz in 7591 ms
# processed file R_2016R3/data_2687.xml.gz in 8105 ms
# processed file R_2016R3/data_2688.xml.gz in 7265 ms
# processed file R_2016R3/data_2689.xml.gz in 7346 ms
# processed file R_2016R3/data_269.xml.gz in 7679 ms
# processed file R_2016R3/data_2690.xml.gz in 7569 ms
# processed file R_2016R3/data_2691.xml.gz in 8418 ms
# processed file R_2016R3/data_2692.xml.gz in 7182 ms
# processed file R_2016R3/data_2693.xml.gz in 7556 ms
# processed file R_2016R3/data_2694.xml.gz in 7447 ms
# processed file R_2016R3/data_2695.xml.gz in 7833 ms
# processed file R_2016R3/data_2696.xml.gz in 7757 ms
# processed file R_2016R3/data_2697.xml.gz in 7466 ms
# processed file R_2016R3/data_2698.xml.gz in 7618 ms
# processed file R_2016R3/data_2699.xml.gz in 7798 ms
# processed file R_2016R3/data_27.xml.gz in 7160 ms
# processed file R_2016R3/data_270.xml.gz in 7809 ms
# processed file R_2016R3/data_2700.xml.gz in 8029 ms
# processed file R_2016R3/data_2701.xml.gz in 7233 ms
# processed file R_2016R3/data_2702.xml.gz in 7578 ms
# processed file R_2016R3/data_2703.xml.gz in 7557 ms
# processed file R_2016R3/data_2704.xml.gz in 8160 ms
# processed file R_2016R3/data_2705.xml.gz in 7294 ms
# processed file R_2016R3/data_2706.xml.gz in 7702 ms
# processed file R_2016R3/data_2707.xml.gz in 7507 ms
# processed file R_2016R3/data_2708.xml.gz in 8167 ms
# processed file R_2016R3/data_2709.xml.gz in 7508 ms
# processed file R_2016R3/data_271.xml.gz in 7378 ms
# processed file R_2016R3/data_2710.xml.gz in 7540 ms
# processed file R_2016R3/data_2711.xml.gz in 7828 ms
# processed file R_2016R3/data_2712.xml.gz in 8144 ms
# processed file R_2016R3/data_2713.xml.gz in 7350 ms
# processed file R_2016R3/data_2714.xml.gz in 7390 ms
# processed file R_2016R3/data_2715.xml.gz in 7807 ms
# processed file R_2016R3/data_2716.xml.gz in 8046 ms
# processed file R_2016R3/data_2717.xml.gz in 7242 ms
# processed file R_2016R3/data_2718.xml.gz in 7532 ms
# processed file R_2016R3/data_2719.xml.gz in 7772 ms
# processed file R_2016R3/data_272.xml.gz in 7455 ms
# processed file R_2016R3/data_2720.xml.gz in 7530 ms
# processed file R_2016R3/data_2721.xml.gz in 7272 ms
# processed file R_2016R3/data_2722.xml.gz in 7917 ms
# processed file R_2016R3/data_2723.xml.gz in 7369 ms
# processed file R_2016R3/data_2724.xml.gz in 7697 ms
# processed file R_2016R3/data_2725.xml.gz in 8248 ms
# processed file R_2016R3/data_2726.xml.gz in 7492 ms
# processed file R_2016R3/data_2727.xml.gz in 7533 ms
# processed file R_2016R3/data_2728.xml.gz in 7672 ms
# processed file R_2016R3/data_2729.xml.gz in 7443 ms
# processed file R_2016R3/data_273.xml.gz in 7979 ms
# processed file R_2016R3/data_2730.xml.gz in 7539 ms
# processed file R_2016R3/data_2731.xml.gz in 8015 ms
# processed file R_2016R3/data_2732.xml.gz in 7497 ms
# processed file R_2016R3/data_2733.xml.gz in 7800 ms
# processed file R_2016R3/data_2734.xml.gz in 7488 ms
# processed file R_2016R3/data_2735.xml.gz in 7188 ms
# processed file R_2016R3/data_2736.xml.gz in 7710 ms
# processed file R_2016R3/data_2737.xml.gz in 7996 ms
# processed file R_2016R3/data_2738.xml.gz in 7552 ms
# processed file R_2016R3/data_2739.xml.gz in 7979 ms
# processed file R_2016R3/data_274.xml.gz in 7129 ms
# processed file R_2016R3/data_2740.xml.gz in 7447 ms
# processed file R_2016R3/data_2741.xml.gz in 7377 ms
# processed file R_2016R3/data_2742.xml.gz in 7809 ms
# processed file R_2016R3/data_2743.xml.gz in 7702 ms
# processed file R_2016R3/data_2744.xml.gz in 7525 ms
# processed file R_2016R3/data_2745.xml.gz in 7943 ms
# processed file R_2016R3/data_2746.xml.gz in 7365 ms
# processed file R_2016R3/data_2747.xml.gz in 7569 ms
# processed file R_2016R3/data_2748.xml.gz in 8351 ms
# processed file R_2016R3/data_2749.xml.gz in 7086 ms
# processed file R_2016R3/data_275.xml.gz in 7778 ms
# processed file R_2016R3/data_2750.xml.gz in 7370 ms
# processed file R_2016R3/data_2751.xml.gz in 7708 ms
# processed file R_2016R3/data_2752.xml.gz in 7371 ms
# processed file R_2016R3/data_2753.xml.gz in 7653 ms
# processed file R_2016R3/data_2754.xml.gz in 8180 ms
# processed file R_2016R3/data_2755.xml.gz in 7387 ms
# processed file R_2016R3/data_2756.xml.gz in 7710 ms
# processed file R_2016R3/data_2757.xml.gz in 7504 ms
# processed file R_2016R3/data_2758.xml.gz in 7296 ms
# processed file R_2016R3/data_2759.xml.gz in 7752 ms
# processed file R_2016R3/data_276.xml.gz in 7558 ms
# processed file R_2016R3/data_2760.xml.gz in 7970 ms
# processed file R_2016R3/data_2761.xml.gz in 7427 ms
# processed file R_2016R3/data_2762.xml.gz in 8142 ms
# processed file R_2016R3/data_2763.xml.gz in 7202 ms
# processed file R_2016R3/data_2764.xml.gz in 7487 ms
# processed file R_2016R3/data_2765.xml.gz in 7744 ms
# processed file R_2016R3/data_2766.xml.gz in 7541 ms
# processed file R_2016R3/data_2767.xml.gz in 7398 ms
# processed file R_2016R3/data_2768.xml.gz in 7776 ms
# processed file R_2016R3/data_2769.xml.gz in 7301 ms
# processed file R_2016R3/data_277.xml.gz in 7838 ms
# processed file R_2016R3/data_2770.xml.gz in 7597 ms
# processed file R_2016R3/data_2771.xml.gz in 7798 ms
# processed file R_2016R3/data_2772.xml.gz in 7640 ms
# processed file R_2016R3/data_2773.xml.gz in 7427 ms
# processed file R_2016R3/data_2774.xml.gz in 7901 ms
# processed file R_2016R3/data_2775.xml.gz in 7275 ms
# processed file R_2016R3/data_2776.xml.gz in 7766 ms
# processed file R_2016R3/data_2777.xml.gz in 8015 ms
# processed file R_2016R3/data_2778.xml.gz in 7487 ms
# processed file R_2016R3/data_2779.xml.gz in 7621 ms
# processed file R_2016R3/data_278.xml.gz in 6686 ms
# processed file R_2016R3/data_2780.xml.gz in 7079 ms
# processed file R_2016R3/data_2781.xml.gz in 7493 ms
# processed file R_2016R3/data_2782.xml.gz in 7524 ms
# processed file R_2016R3/data_2783.xml.gz in 8031 ms
# processed file R_2016R3/data_2784.xml.gz in 7557 ms
# processed file R_2016R3/data_2785.xml.gz in 7433 ms
# processed file R_2016R3/data_2786.xml.gz in 7552 ms
# processed file R_2016R3/data_2787.xml.gz in 7610 ms
# processed file R_2016R3/data_2788.xml.gz in 7730 ms
# processed file R_2016R3/data_2789.xml.gz in 7814 ms
# processed file R_2016R3/data_279.xml.gz in 7481 ms
# processed file R_2016R3/data_2790.xml.gz in 7455 ms
# processed file R_2016R3/data_2791.xml.gz in 7943 ms
# processed file R_2016R3/data_2792.xml.gz in 7390 ms
# processed file R_2016R3/data_2793.xml.gz in 7393 ms
# processed file R_2016R3/data_2794.xml.gz in 7812 ms
# processed file R_2016R3/data_2795.xml.gz in 7523 ms
# processed file R_2016R3/data_2796.xml.gz in 7412 ms
# processed file R_2016R3/data_2797.xml.gz in 7972 ms
# processed file R_2016R3/data_2798.xml.gz in 7535 ms
# processed file R_2016R3/data_2799.xml.gz in 7451 ms
# processed file R_2016R3/data_28.xml.gz in 7091 ms
# processed file R_2016R3/data_280.xml.gz in 7791 ms
# processed file R_2016R3/data_2800.xml.gz in 8070 ms
# processed file R_2016R3/data_2801.xml.gz in 7252 ms
# processed file R_2016R3/data_2802.xml.gz in 7664 ms
# processed file R_2016R3/data_2803.xml.gz in 7729 ms
# processed file R_2016R3/data_2804.xml.gz in 7629 ms
# processed file R_2016R3/data_2805.xml.gz in 7661 ms
# processed file R_2016R3/data_2806.xml.gz in 7753 ms
# processed file R_2016R3/data_2807.xml.gz in 7272 ms
# processed file R_2016R3/data_2808.xml.gz in 8034 ms
# processed file R_2016R3/data_2809.xml.gz in 7087 ms
# processed file R_2016R3/data_281.xml.gz in 8201 ms
# processed file R_2016R3/data_2810.xml.gz in 6867 ms
# processed file R_2016R3/data_2811.xml.gz in 7009 ms
# processed file R_2016R3/data_2812.xml.gz in 7014 ms
# processed file R_2016R3/data_2813.xml.gz in 6912 ms
# processed file R_2016R3/data_2814.xml.gz in 6821 ms
# processed file R_2016R3/data_2815.xml.gz in 7504 ms
# processed file R_2016R3/data_2816.xml.gz in 7431 ms
# processed file R_2016R3/data_2817.xml.gz in 7458 ms
# processed file R_2016R3/data_2818.xml.gz in 7424 ms
# processed file R_2016R3/data_2819.xml.gz in 7583 ms
# processed file R_2016R3/data_282.xml.gz in 7123 ms
# processed file R_2016R3/data_2820.xml.gz in 7528 ms
# processed file R_2016R3/data_2821.xml.gz in 7357 ms
# processed file R_2016R3/data_2822.xml.gz in 7238 ms
# processed file R_2016R3/data_2823.xml.gz in 7541 ms
# processed file R_2016R3/data_2824.xml.gz in 7289 ms
# processed file R_2016R3/data_2825.xml.gz in 7412 ms
# processed file R_2016R3/data_2826.xml.gz in 7479 ms
# processed file R_2016R3/data_2827.xml.gz in 7350 ms
# processed file R_2016R3/data_2828.xml.gz in 7202 ms
# processed file R_2016R3/data_2829.xml.gz in 7213 ms
# processed file R_2016R3/data_283.xml.gz in 7795 ms
# processed file R_2016R3/data_2830.xml.gz in 7549 ms
# processed file R_2016R3/data_2831.xml.gz in 7484 ms
# processed file R_2016R3/data_2832.xml.gz in 7526 ms
# processed file R_2016R3/data_2833.xml.gz in 7725 ms
# processed file R_2016R3/data_2834.xml.gz in 7889 ms
# processed file R_2016R3/data_2835.xml.gz in 7528 ms
# processed file R_2016R3/data_2836.xml.gz in 7081 ms
# processed file R_2016R3/data_2837.xml.gz in 7341 ms
# processed file R_2016R3/data_2838.xml.gz in 7408 ms
# processed file R_2016R3/data_2839.xml.gz in 7607 ms
# processed file R_2016R3/data_284.xml.gz in 7444 ms
# processed file R_2016R3/data_2840.xml.gz in 7686 ms
# processed file R_2016R3/data_2841.xml.gz in 7466 ms
# processed file R_2016R3/data_2842.xml.gz in 7232 ms
# processed file R_2016R3/data_2843.xml.gz in 7154 ms
# processed file R_2016R3/data_2844.xml.gz in 7575 ms
# processed file R_2016R3/data_2845.xml.gz in 7562 ms
# processed file R_2016R3/data_2846.xml.gz in 7041 ms
# processed file R_2016R3/data_2847.xml.gz in 7469 ms
# processed file R_2016R3/data_2848.xml.gz in 7435 ms
# processed file R_2016R3/data_2849.xml.gz in 7837 ms
# processed file R_2016R3/data_285.xml.gz in 7784 ms
# processed file R_2016R3/data_2850.xml.gz in 7420 ms
# processed file R_2016R3/data_2851.xml.gz in 7425 ms
# processed file R_2016R3/data_2852.xml.gz in 7527 ms
# processed file R_2016R3/data_2853.xml.gz in 7617 ms
# processed file R_2016R3/data_2854.xml.gz in 6951 ms
# processed file R_2016R3/data_2855.xml.gz in 7681 ms
# processed file R_2016R3/data_2856.xml.gz in 7512 ms
# processed file R_2016R3/data_2857.xml.gz in 7973 ms
# processed file R_2016R3/data_2858.xml.gz in 7246 ms
# processed file R_2016R3/data_2859.xml.gz in 7515 ms
# processed file R_2016R3/data_286.xml.gz in 7610 ms
# processed file R_2016R3/data_2860.xml.gz in 7414 ms
# processed file R_2016R3/data_2861.xml.gz in 7212 ms
# processed file R_2016R3/data_2862.xml.gz in 7429 ms
# processed file R_2016R3/data_2863.xml.gz in 7616 ms
# processed file R_2016R3/data_2864.xml.gz in 7251 ms
# processed file R_2016R3/data_2865.xml.gz in 6973 ms
# processed file R_2016R3/data_2866.xml.gz in 7211 ms
# processed file R_2016R3/data_2867.xml.gz in 7134 ms
# processed file R_2016R3/data_2868.xml.gz in 7340 ms
# processed file R_2016R3/data_2869.xml.gz in 7097 ms
# processed file R_2016R3/data_287.xml.gz in 7347 ms
# processed file R_2016R3/data_2870.xml.gz in 6994 ms
# processed file R_2016R3/data_2871.xml.gz in 7615 ms
# processed file R_2016R3/data_2872.xml.gz in 7275 ms
# processed file R_2016R3/data_2873.xml.gz in 7888 ms
# processed file R_2016R3/data_2874.xml.gz in 7539 ms
# processed file R_2016R3/data_2875.xml.gz in 7393 ms
# processed file R_2016R3/data_2876.xml.gz in 7192 ms
# processed file R_2016R3/data_2877.xml.gz in 7596 ms
# processed file R_2016R3/data_2878.xml.gz in 7324 ms
# processed file R_2016R3/data_2879.xml.gz in 7337 ms
# processed file R_2016R3/data_288.xml.gz in 7322 ms
# processed file R_2016R3/data_2880.xml.gz in 7527 ms
# processed file R_2016R3/data_2881.xml.gz in 7463 ms
# processed file R_2016R3/data_2882.xml.gz in 7366 ms
# processed file R_2016R3/data_2883.xml.gz in 7504 ms
# processed file R_2016R3/data_2884.xml.gz in 7560 ms
# processed file R_2016R3/data_2885.xml.gz in 7532 ms
# processed file R_2016R3/data_2886.xml.gz in 7490 ms
# processed file R_2016R3/data_2887.xml.gz in 7436 ms
# processed file R_2016R3/data_2888.xml.gz in 7282 ms
# processed file R_2016R3/data_2889.xml.gz in 7494 ms
# processed file R_2016R3/data_289.xml.gz in 7481 ms
# processed file R_2016R3/data_2890.xml.gz in 7291 ms
# processed file R_2016R3/data_2891.xml.gz in 7358 ms
# processed file R_2016R3/data_2892.xml.gz in 7449 ms
# processed file R_2016R3/data_2893.xml.gz in 7463 ms
# processed file R_2016R3/data_2894.xml.gz in 7493 ms
# processed file R_2016R3/data_2895.xml.gz in 5900 ms
# processed file R_2016R3/data_2896.xml.gz in 6102 ms
# processed file R_2016R3/data_2897.xml.gz in 10096 ms
# processed file R_2016R3/data_2898.xml.gz in 10470 ms
# processed file R_2016R3/data_2899.xml.gz in 10382 ms
# processed file R_2016R3/data_29.xml.gz in 6795 ms
# processed file R_2016R3/data_290.xml.gz in 7341 ms
# processed file R_2016R3/data_2900.xml.gz in 9828 ms
# processed file R_2016R3/data_2901.xml.gz in 12341 ms
# processed file R_2016R3/data_2902.xml.gz in 6625 ms
# processed file R_2016R3/data_2903.xml.gz in 6990 ms
# processed file R_2016R3/data_2904.xml.gz in 7378 ms
# processed file R_2016R3/data_2905.xml.gz in 7066 ms
# processed file R_2016R3/data_2906.xml.gz in 6957 ms
# processed file R_2016R3/data_2907.xml.gz in 7108 ms
# processed file R_2016R3/data_2908.xml.gz in 6966 ms
# processed file R_2016R3/data_2909.xml.gz in 7060 ms
# processed file R_2016R3/data_291.xml.gz in 7531 ms
# processed file R_2016R3/data_2910.xml.gz in 7077 ms
# processed file R_2016R3/data_2911.xml.gz in 7182 ms
# processed file R_2016R3/data_2912.xml.gz in 7252 ms
# processed file R_2016R3/data_2913.xml.gz in 7244 ms
# processed file R_2016R3/data_2914.xml.gz in 7434 ms
# processed file R_2016R3/data_2915.xml.gz in 7102 ms
# processed file R_2016R3/data_2916.xml.gz in 7325 ms
# processed file R_2016R3/data_2917.xml.gz in 7857 ms
# processed file R_2016R3/data_2918.xml.gz in 7159 ms
# processed file R_2016R3/data_2919.xml.gz in 7580 ms
# processed file R_2016R3/data_292.xml.gz in 7706 ms
# processed file R_2016R3/data_2920.xml.gz in 7079 ms
# processed file R_2016R3/data_2921.xml.gz in 7125 ms
# processed file R_2016R3/data_2922.xml.gz in 7334 ms
# processed file R_2016R3/data_2923.xml.gz in 7368 ms
# processed file R_2016R3/data_2924.xml.gz in 7741 ms
# processed file R_2016R3/data_2925.xml.gz in 7520 ms
# processed file R_2016R3/data_2926.xml.gz in 7376 ms
# processed file R_2016R3/data_2927.xml.gz in 7259 ms
# processed file R_2016R3/data_2928.xml.gz in 7909 ms
# processed file R_2016R3/data_2929.xml.gz in 7265 ms
# processed file R_2016R3/data_293.xml.gz in 7439 ms
# processed file R_2016R3/data_2930.xml.gz in 6994 ms
# processed file R_2016R3/data_2931.xml.gz in 7167 ms
# processed file R_2016R3/data_2932.xml.gz in 7097 ms
# processed file R_2016R3/data_2933.xml.gz in 7272 ms
# processed file R_2016R3/data_2934.xml.gz in 7927 ms
# processed file R_2016R3/data_2935.xml.gz in 6913 ms
# processed file R_2016R3/data_2936.xml.gz in 7420 ms
# processed file R_2016R3/data_2937.xml.gz in 7410 ms
# processed file R_2016R3/data_2938.xml.gz in 7434 ms
# processed file R_2016R3/data_2939.xml.gz in 7162 ms
# processed file R_2016R3/data_294.xml.gz in 7525 ms
# processed file R_2016R3/data_2940.xml.gz in 7224 ms
# processed file R_2016R3/data_2941.xml.gz in 7592 ms
# processed file R_2016R3/data_2942.xml.gz in 6976 ms
# processed file R_2016R3/data_2943.xml.gz in 7137 ms
# processed file R_2016R3/data_2944.xml.gz in 7045 ms
# processed file R_2016R3/data_2945.xml.gz in 7601 ms
# processed file R_2016R3/data_2946.xml.gz in 7115 ms
# processed file R_2016R3/data_2947.xml.gz in 7252 ms
# processed file R_2016R3/data_2948.xml.gz in 7305 ms
# processed file R_2016R3/data_2949.xml.gz in 7383 ms
# processed file R_2016R3/data_295.xml.gz in 7522 ms
# processed file R_2016R3/data_2950.xml.gz in 7662 ms
# processed file R_2016R3/data_2951.xml.gz in 7135 ms
# processed file R_2016R3/data_2952.xml.gz in 7295 ms
# processed file R_2016R3/data_2953.xml.gz in 7447 ms
# processed file R_2016R3/data_2954.xml.gz in 7408 ms
# processed file R_2016R3/data_2955.xml.gz in 6954 ms
# processed file R_2016R3/data_2956.xml.gz in 7401 ms
# processed file R_2016R3/data_2957.xml.gz in 7027 ms
# processed file R_2016R3/data_2958.xml.gz in 7020 ms
# processed file R_2016R3/data_2959.xml.gz in 7337 ms
# processed file R_2016R3/data_296.xml.gz in 7468 ms
# processed file R_2016R3/data_2960.xml.gz in 7610 ms
# processed file R_2016R3/data_2961.xml.gz in 7169 ms
# processed file R_2016R3/data_2962.xml.gz in 7322 ms
# processed file R_2016R3/data_2963.xml.gz in 7584 ms
# processed file R_2016R3/data_2964.xml.gz in 7115 ms
# processed file R_2016R3/data_2965.xml.gz in 7605 ms
# processed file R_2016R3/data_2966.xml.gz in 6680 ms
# processed file R_2016R3/data_2967.xml.gz in 7217 ms
# processed file R_2016R3/data_2968.xml.gz in 7473 ms
# processed file R_2016R3/data_2969.xml.gz in 7103 ms
# processed file R_2016R3/data_297.xml.gz in 7285 ms
# processed file R_2016R3/data_2970.xml.gz in 7086 ms
# processed file R_2016R3/data_2971.xml.gz in 7466 ms
# processed file R_2016R3/data_2972.xml.gz in 6810 ms
# processed file R_2016R3/data_2973.xml.gz in 6947 ms
# processed file R_2016R3/data_2974.xml.gz in 7026 ms
# processed file R_2016R3/data_2975.xml.gz in 7133 ms
# processed file R_2016R3/data_2976.xml.gz in 7495 ms
# processed file R_2016R3/data_2977.xml.gz in 7135 ms
# processed file R_2016R3/data_2978.xml.gz in 7428 ms
# processed file R_2016R3/data_2979.xml.gz in 7323 ms
# processed file R_2016R3/data_298.xml.gz in 7336 ms
# processed file R_2016R3/data_2980.xml.gz in 7090 ms
# processed file R_2016R3/data_2981.xml.gz in 7348 ms
# processed file R_2016R3/data_2982.xml.gz in 7203 ms
# processed file R_2016R3/data_2983.xml.gz in 7235 ms
# processed file R_2016R3/data_2984.xml.gz in 7140 ms
# processed file R_2016R3/data_2985.xml.gz in 7046 ms
# ...
# processed file R_2016R3/data_716.xml.gz in 6876 ms
# processed file R_2016R3/data_717.xml.gz in 7427 ms
# processed file R_2016R3/data_718.xml.gz in 7092 ms
# processed file R_2016R3/data_719.xml.gz in 7354 ms
# processed file R_2016R3/data_72.xml.gz in 7113 ms
# processed file R_2016R3/data_720.xml.gz in 7659 ms
# processed file R_2016R3/data_721.xml.gz in 7510 ms
# processed file R_2016R3/data_722.xml.gz in 7561 ms
# processed file R_2016R3/data_723.xml.gz in 7406 ms
# processed file R_2016R3/data_724.xml.gz in 7208 ms
# processed file R_2016R3/data_725.xml.gz in 7296 ms
# processed file R_2016R3/data_726.xml.gz in 7609 ms
# processed file R_2016R3/data_727.xml.gz in 7098 ms
# processed file R_2016R3/data_728.xml.gz in 7509 ms
# processed file R_2016R3/data_729.xml.gz in 7530 ms
# processed file R_2016R3/data_73.xml.gz in 6803 ms
# processed file R_2016R3/data_730.xml.gz in 7354 ms
# processed file R_2016R3/data_731.xml.gz in 7026 ms
# processed file R_2016R3/data_732.xml.gz in 7606 ms
# processed file R_2016R3/data_733.xml.gz in 7279 ms
# processed file R_2016R3/data_734.xml.gz in 7260 ms
# processed file R_2016R3/data_735.xml.gz in 7049 ms
# processed file R_2016R3/data_736.xml.gz in 6949 ms
# processed file R_2016R3/data_737.xml.gz in 6948 ms
# processed file R_2016R3/data_738.xml.gz in 7034 ms
# processed file R_2016R3/data_739.xml.gz in 6866 ms
# processed file R_2016R3/data_74.xml.gz in 7097 ms
# processed file R_2016R3/data_740.xml.gz in 6845 ms
# processed file R_2016R3/data_741.xml.gz in 7360 ms
# processed file R_2016R3/data_742.xml.gz in 6904 ms
# processed file R_2016R3/data_743.xml.gz in 7250 ms
# processed file R_2016R3/data_744.xml.gz in 7044 ms
# processed file R_2016R3/data_745.xml.gz in 7206 ms
# processed file R_2016R3/data_746.xml.gz in 7321 ms
# processed file R_2016R3/data_747.xml.gz in 7295 ms
# processed file R_2016R3/data_748.xml.gz in 7386 ms
# processed file R_2016R3/data_749.xml.gz in 7341 ms
# processed file R_2016R3/data_75.xml.gz in 6960 ms
# processed file R_2016R3/data_750.xml.gz in 7635 ms
# processed file R_2016R3/data_751.xml.gz in 7106 ms
# processed file R_2016R3/data_752.xml.gz in 7338 ms
# processed file R_2016R3/data_753.xml.gz in 7789 ms
# processed file R_2016R3/data_754.xml.gz in 7398 ms
# processed file R_2016R3/data_755.xml.gz in 7312 ms
# processed file R_2016R3/data_756.xml.gz in 7363 ms
# processed file R_2016R3/data_757.xml.gz in 7176 ms
# processed file R_2016R3/data_758.xml.gz in 8181 ms
# processed file R_2016R3/data_759.xml.gz in 7267 ms
# processed file R_2016R3/data_76.xml.gz in 6872 ms
# processed file R_2016R3/data_760.xml.gz in 7353 ms
# processed file R_2016R3/data_761.xml.gz in 7382 ms
# processed file R_2016R3/data_762.xml.gz in 7730 ms
# processed file R_2016R3/data_763.xml.gz in 7327 ms
# processed file R_2016R3/data_764.xml.gz in 7578 ms
# processed file R_2016R3/data_765.xml.gz in 7390 ms
# processed file R_2016R3/data_766.xml.gz in 7621 ms
# processed file R_2016R3/data_767.xml.gz in 7014 ms
# processed file R_2016R3/data_768.xml.gz in 7081 ms
# processed file R_2016R3/data_769.xml.gz in 7237 ms
# processed file R_2016R3/data_77.xml.gz in 6985 ms
# processed file R_2016R3/data_770.xml.gz in 7469 ms
# processed file R_2016R3/data_771.xml.gz in 7489 ms
# processed file R_2016R3/data_772.xml.gz in 7486 ms
# processed file R_2016R3/data_773.xml.gz in 7147 ms
# processed file R_2016R3/data_774.xml.gz in 7164 ms
# processed file R_2016R3/data_775.xml.gz in 7165 ms
# processed file R_2016R3/data_776.xml.gz in 7076 ms
# processed file R_2016R3/data_777.xml.gz in 7134 ms
# processed file R_2016R3/data_778.xml.gz in 7195 ms
# processed file R_2016R3/data_779.xml.gz in 7127 ms
# processed file R_2016R3/data_78.xml.gz in 6844 ms
# processed file R_2016R3/data_780.xml.gz in 7425 ms
# processed file R_2016R3/data_781.xml.gz in 7385 ms
# processed file R_2016R3/data_782.xml.gz in 7627 ms
# processed file R_2016R3/data_783.xml.gz in 7456 ms
# processed file R_2016R3/data_784.xml.gz in 7433 ms
# processed file R_2016R3/data_785.xml.gz in 7534 ms
# processed file R_2016R3/data_786.xml.gz in 7401 ms
# processed file R_2016R3/data_787.xml.gz in 7404 ms
# processed file R_2016R3/data_788.xml.gz in 7052 ms
# processed file R_2016R3/data_789.xml.gz in 7500 ms
# processed file R_2016R3/data_79.xml.gz in 6762 ms
# processed file R_2016R3/data_790.xml.gz in 7620 ms
# processed file R_2016R3/data_791.xml.gz in 7127 ms
# processed file R_2016R3/data_792.xml.gz in 7831 ms
# processed file R_2016R3/data_793.xml.gz in 7379 ms
# processed file R_2016R3/data_794.xml.gz in 7572 ms
# processed file R_2016R3/data_795.xml.gz in 7660 ms
# processed file R_2016R3/data_796.xml.gz in 7311 ms
# processed file R_2016R3/data_797.xml.gz in 7375 ms
# processed file R_2016R3/data_798.xml.gz in 8482 ms
# processed file R_2016R3/data_799.xml.gz in 7696 ms
# processed file R_2016R3/data_8.xml.gz in 7077 ms
# processed file R_2016R3/data_80.xml.gz in 6772 ms
# processed file R_2016R3/data_800.xml.gz in 7754 ms
# processed file R_2016R3/data_801.xml.gz in 7748 ms
# processed file R_2016R3/data_802.xml.gz in 7675 ms
# processed file R_2016R3/data_803.xml.gz in 7686 ms
# processed file R_2016R3/data_804.xml.gz in 7824 ms
# processed file R_2016R3/data_805.xml.gz in 7809 ms
# processed file R_2016R3/data_806.xml.gz in 7915 ms
# processed file R_2016R3/data_807.xml.gz in 7501 ms
# processed file R_2016R3/data_808.xml.gz in 7561 ms
# processed file R_2016R3/data_809.xml.gz in 7376 ms
# processed file R_2016R3/data_81.xml.gz in 7089 ms
# processed file R_2016R3/data_810.xml.gz in 7431 ms
# processed file R_2016R3/data_811.xml.gz in 7680 ms
# processed file R_2016R3/data_812.xml.gz in 7373 ms
# processed file R_2016R3/data_813.xml.gz in 7350 ms
# processed file R_2016R3/data_814.xml.gz in 7590 ms
# processed file R_2016R3/data_815.xml.gz in 7589 ms
# processed file R_2016R3/data_816.xml.gz in 7299 ms
# processed file R_2016R3/data_817.xml.gz in 8012 ms
# processed file R_2016R3/data_818.xml.gz in 7099 ms
# processed file R_2016R3/data_819.xml.gz in 7648 ms
# processed file R_2016R3/data_82.xml.gz in 7071 ms
# processed file R_2016R3/data_820.xml.gz in 7496 ms
# processed file R_2016R3/data_821.xml.gz in 7606 ms
# processed file R_2016R3/data_822.xml.gz in 7527 ms
# processed file R_2016R3/data_823.xml.gz in 7358 ms
# processed file R_2016R3/data_824.xml.gz in 7627 ms
# processed file R_2016R3/data_825.xml.gz in 7763 ms
# processed file R_2016R3/data_826.xml.gz in 7231 ms
# processed file R_2016R3/data_827.xml.gz in 7718 ms
# processed file R_2016R3/data_828.xml.gz in 7715 ms
# processed file R_2016R3/data_829.xml.gz in 7859 ms
# processed file R_2016R3/data_83.xml.gz in 6895 ms
# processed file R_2016R3/data_830.xml.gz in 7649 ms
# processed file R_2016R3/data_831.xml.gz in 7453 ms
# processed file R_2016R3/data_832.xml.gz in 7401 ms
# processed file R_2016R3/data_833.xml.gz in 7411 ms
# processed file R_2016R3/data_834.xml.gz in 7623 ms
# processed file R_2016R3/data_835.xml.gz in 7589 ms
# processed file R_2016R3/data_836.xml.gz in 7476 ms
# processed file R_2016R3/data_837.xml.gz in 7481 ms
# processed file R_2016R3/data_838.xml.gz in 7604 ms
# processed file R_2016R3/data_839.xml.gz in 7394 ms
# processed file R_2016R3/data_84.xml.gz in 7096 ms
# processed file R_2016R3/data_840.xml.gz in 7850 ms
# processed file R_2016R3/data_841.xml.gz in 7350 ms
# processed file R_2016R3/data_842.xml.gz in 7633 ms
# processed file R_2016R3/data_843.xml.gz in 7487 ms
# processed file R_2016R3/data_844.xml.gz in 7416 ms
# processed file R_2016R3/data_845.xml.gz in 7440 ms
# processed file R_2016R3/data_846.xml.gz in 7639 ms
# processed file R_2016R3/data_847.xml.gz in 7779 ms
# processed file R_2016R3/data_848.xml.gz in 7369 ms
# processed file R_2016R3/data_849.xml.gz in 7292 ms
# processed file R_2016R3/data_85.xml.gz in 6984 ms
# processed file R_2016R3/data_850.xml.gz in 7405 ms
# processed file R_2016R3/data_851.xml.gz in 7539 ms
# processed file R_2016R3/data_852.xml.gz in 7267 ms
# processed file R_2016R3/data_853.xml.gz in 7268 ms
# processed file R_2016R3/data_854.xml.gz in 7624 ms
# processed file R_2016R3/data_855.xml.gz in 7189 ms
# processed file R_2016R3/data_856.xml.gz in 7183 ms
# processed file R_2016R3/data_857.xml.gz in 7815 ms
# processed file R_2016R3/data_858.xml.gz in 7319 ms
# processed file R_2016R3/data_859.xml.gz in 7459 ms
# processed file R_2016R3/data_86.xml.gz in 7045 ms
# processed file R_2016R3/data_860.xml.gz in 7977 ms
# processed file R_2016R3/data_861.xml.gz in 7276 ms
# processed file R_2016R3/data_862.xml.gz in 7864 ms
# processed file R_2016R3/data_863.xml.gz in 7527 ms
# processed file R_2016R3/data_864.xml.gz in 7591 ms
# processed file R_2016R3/data_865.xml.gz in 7347 ms
# processed file R_2016R3/data_866.xml.gz in 7519 ms
# processed file R_2016R3/data_867.xml.gz in 7387 ms
# processed file R_2016R3/data_868.xml.gz in 7626 ms
# processed file R_2016R3/data_869.xml.gz in 7719 ms
# processed file R_2016R3/data_87.xml.gz in 6753 ms
# processed file R_2016R3/data_870.xml.gz in 7058 ms
# processed file R_2016R3/data_871.xml.gz in 7455 ms
# processed file R_2016R3/data_872.xml.gz in 7713 ms
# processed file R_2016R3/data_873.xml.gz in 7392 ms
# processed file R_2016R3/data_874.xml.gz in 7425 ms
# processed file R_2016R3/data_875.xml.gz in 7517 ms
# processed file R_2016R3/data_876.xml.gz in 7397 ms
# processed file R_2016R3/data_877.xml.gz in 7574 ms
# processed file R_2016R3/data_878.xml.gz in 7637 ms
# processed file R_2016R3/data_879.xml.gz in 7439 ms
# processed file R_2016R3/data_88.xml.gz in 6827 ms
# processed file R_2016R3/data_880.xml.gz in 7890 ms
# processed file R_2016R3/data_881.xml.gz in 7566 ms
# processed file R_2016R3/data_882.xml.gz in 7499 ms
# processed file R_2016R3/data_883.xml.gz in 7266 ms
# processed file R_2016R3/data_884.xml.gz in 7414 ms
# processed file R_2016R3/data_885.xml.gz in 7377 ms
# processed file R_2016R3/data_886.xml.gz in 7518 ms
# processed file R_2016R3/data_887.xml.gz in 7286 ms
# processed file R_2016R3/data_888.xml.gz in 7549 ms
# processed file R_2016R3/data_889.xml.gz in 7747 ms
# processed file R_2016R3/data_89.xml.gz in 7230 ms
# processed file R_2016R3/data_890.xml.gz in 7997 ms
# processed file R_2016R3/data_891.xml.gz in 6885 ms
# processed file R_2016R3/data_892.xml.gz in 6706 ms
# processed file R_2016R3/data_893.xml.gz in 6870 ms
# processed file R_2016R3/data_894.xml.gz in 7516 ms
# processed file R_2016R3/data_895.xml.gz in 7139 ms
# processed file R_2016R3/data_896.xml.gz in 7277 ms
# processed file R_2016R3/data_897.xml.gz in 7788 ms
# processed file R_2016R3/data_898.xml.gz in 7155 ms
# processed file R_2016R3/data_899.xml.gz in 7428 ms
# processed file R_2016R3/data_9.xml.gz in 7113 ms
# processed file R_2016R3/data_90.xml.gz in 6992 ms
# processed file R_2016R3/data_900.xml.gz in 7366 ms
# processed file R_2016R3/data_901.xml.gz in 7391 ms
# processed file R_2016R3/data_902.xml.gz in 7570 ms
# processed file R_2016R3/data_903.xml.gz in 7452 ms
# processed file R_2016R3/data_904.xml.gz in 7400 ms
# processed file R_2016R3/data_905.xml.gz in 7094 ms
# processed file R_2016R3/data_906.xml.gz in 7444 ms
# processed file R_2016R3/data_907.xml.gz in 7421 ms
# processed file R_2016R3/data_908.xml.gz in 7445 ms
# processed file R_2016R3/data_909.xml.gz in 7510 ms
# processed file R_2016R3/data_91.xml.gz in 6852 ms
# processed file R_2016R3/data_910.xml.gz in 7446 ms
# processed file R_2016R3/data_911.xml.gz in 7460 ms
# processed file R_2016R3/data_912.xml.gz in 6960 ms
# processed file R_2016R3/data_913.xml.gz in 7694 ms
# processed file R_2016R3/data_914.xml.gz in 7243 ms
# processed file R_2016R3/data_915.xml.gz in 7517 ms
# processed file R_2016R3/data_916.xml.gz in 7357 ms
# processed file R_2016R3/data_917.xml.gz in 7432 ms
# processed file R_2016R3/data_918.xml.gz in 7505 ms
# processed file R_2016R3/data_919.xml.gz in 7563 ms
# processed file R_2016R3/data_92.xml.gz in 6912 ms
# processed file R_2016R3/data_920.xml.gz in 7310 ms
# processed file R_2016R3/data_921.xml.gz in 7329 ms
# processed file R_2016R3/data_922.xml.gz in 7826 ms
# processed file R_2016R3/data_923.xml.gz in 7520 ms
# processed file R_2016R3/data_924.xml.gz in 7540 ms
# processed file R_2016R3/data_925.xml.gz in 7266 ms
# processed file R_2016R3/data_926.xml.gz in 7597 ms
# processed file R_2016R3/data_927.xml.gz in 7524 ms
# processed file R_2016R3/data_928.xml.gz in 7761 ms
# processed file R_2016R3/data_929.xml.gz in 7197 ms
# processed file R_2016R3/data_93.xml.gz in 7178 ms
# processed file R_2016R3/data_930.xml.gz in 7382 ms
# processed file R_2016R3/data_931.xml.gz in 7505 ms
# processed file R_2016R3/data_932.xml.gz in 7324 ms
# processed file R_2016R3/data_933.xml.gz in 7806 ms
# processed file R_2016R3/data_934.xml.gz in 7484 ms
# processed file R_2016R3/data_935.xml.gz in 7463 ms
# processed file R_2016R3/data_936.xml.gz in 7481 ms
# processed file R_2016R3/data_937.xml.gz in 7319 ms
# processed file R_2016R3/data_938.xml.gz in 7436 ms
# processed file R_2016R3/data_939.xml.gz in 7613 ms
# processed file R_2016R3/data_94.xml.gz in 6656 ms
# processed file R_2016R3/data_940.xml.gz in 7808 ms
# processed file R_2016R3/data_941.xml.gz in 7584 ms
# processed file R_2016R3/data_942.xml.gz in 7624 ms
# processed file R_2016R3/data_943.xml.gz in 7183 ms
# processed file R_2016R3/data_944.xml.gz in 7573 ms
# processed file R_2016R3/data_945.xml.gz in 7128 ms
# processed file R_2016R3/data_946.xml.gz in 7569 ms
# processed file R_2016R3/data_947.xml.gz in 7292 ms
# processed file R_2016R3/data_948.xml.gz in 7459 ms
# processed file R_2016R3/data_949.xml.gz in 7552 ms
# processed file R_2016R3/data_95.xml.gz in 6803 ms
# processed file R_2016R3/data_950.xml.gz in 7756 ms
# processed file R_2016R3/data_951.xml.gz in 7587 ms
# processed file R_2016R3/data_952.xml.gz in 7269 ms
# processed file R_2016R3/data_953.xml.gz in 7723 ms
# processed file R_2016R3/data_954.xml.gz in 7359 ms
# processed file R_2016R3/data_955.xml.gz in 7438 ms
# processed file R_2016R3/data_956.xml.gz in 7298 ms
# processed file R_2016R3/data_957.xml.gz in 7287 ms
# processed file R_2016R3/data_958.xml.gz in 7444 ms
# processed file R_2016R3/data_959.xml.gz in 7456 ms
# processed file R_2016R3/data_96.xml.gz in 6923 ms
# processed file R_2016R3/data_960.xml.gz in 7391 ms
# processed file R_2016R3/data_961.xml.gz in 7465 ms
# processed file R_2016R3/data_962.xml.gz in 7913 ms
# processed file R_2016R3/data_963.xml.gz in 7359 ms
# processed file R_2016R3/data_964.xml.gz in 7402 ms
# processed file R_2016R3/data_965.xml.gz in 7660 ms
# processed file R_2016R3/data_966.xml.gz in 7334 ms
# processed file R_2016R3/data_967.xml.gz in 7401 ms
# processed file R_2016R3/data_968.xml.gz in 7665 ms
# processed file R_2016R3/data_969.xml.gz in 7179 ms
# processed file R_2016R3/data_97.xml.gz in 7020 ms
# processed file R_2016R3/data_970.xml.gz in 7320 ms
# processed file R_2016R3/data_971.xml.gz in 7648 ms
# processed file R_2016R3/data_972.xml.gz in 7243 ms
# processed file R_2016R3/data_973.xml.gz in 7458 ms
# processed file R_2016R3/data_974.xml.gz in 7295 ms
# processed file R_2016R3/data_975.xml.gz in 7512 ms
# processed file R_2016R3/data_976.xml.gz in 7239 ms
# processed file R_2016R3/data_977.xml.gz in 8030 ms
# processed file R_2016R3/data_978.xml.gz in 7469 ms
# processed file R_2016R3/data_979.xml.gz in 7457 ms
# processed file R_2016R3/data_98.xml.gz in 6789 ms
# processed file R_2016R3/data_980.xml.gz in 7921 ms
# processed file R_2016R3/data_981.xml.gz in 7267 ms
# processed file R_2016R3/data_982.xml.gz in 7754 ms
# processed file R_2016R3/data_983.xml.gz in 7417 ms
# processed file R_2016R3/data_984.xml.gz in 7793 ms
# processed file R_2016R3/data_985.xml.gz in 7736 ms
# processed file R_2016R3/data_986.xml.gz in 7197 ms
# processed file R_2016R3/data_987.xml.gz in 7331 ms
# processed file R_2016R3/data_988.xml.gz in 7503 ms
# processed file R_2016R3/data_989.xml.gz in 7233 ms
# processed file R_2016R3/data_99.xml.gz in 7306 ms
# processed file R_2016R3/data_990.xml.gz in 7531 ms
# processed file R_2016R3/data_991.xml.gz in 7675 ms
# processed file R_2016R3/data_992.xml.gz in 7349 ms
# processed file R_2016R3/data_993.xml.gz in 7515 ms
# processed file R_2016R3/data_994.xml.gz in 6958 ms
# processed file R_2016R3/data_995.xml.gz in 6994 ms
# processed file R_2016R3/data_996.xml.gz in 7142 ms
# processed file R_2016R3/data_997.xml.gz in 7233 ms
# processed file R_2016R3/data_998.xml.gz in 6903 ms
# processed file R_2016R3/data_999.xml.gz in 7061 ms

# %%
print(processingmessage)
# Out:
# processed 4399 files in 34267s

# %% [markdown]
# # Analyzing data
#
# ## Counting database artfacts

# %%
q2="""
MATCH (n) return "node" as entity, count(n) as count
UNION ALL
MATCH ()-[r]->() return "relationship" as entity, count(r) as count
UNION ALL
CALL db.labels() yield label return "label" as entity, count(label) as count
UNION ALL 
CALL db.relationshipTypes() yield relationshipType return "relationshipType" as entity, count(relationshipType) as count
UNION ALL 
CALL db.propertyKeys() yield propertyKey return "propertyKey" as entity, count(propertyKey) as count
"""
run_cypher(session, q2)
# Out:
# run_cypher : MATCH (n) return "node" as entity, count(n) as countUNION ALLMATCH ()-[r]-...
# Results available after 49ms, finished query after 742ms
#                      count
# entity
# node               5687323
# relationship      16486017
# label                  324
# relationshipType        92
# propertyKey           3319

# %% [markdown]
# #### Size on disk 4.3G (du -h . in the [neo4j_data_home]/databases directory)
# #### It takes about 8 seconds to process a db file with Python to process 5682 files takes about 12.6 hours
# When using a compiled language this will be a bit faster

# %% [markdown]
# ## Checking relationship structures
# When eploring the graph we found a lot of bi directional relationships between classes.
# The query below will count the possible relationship combination between two nodes.

# %%
q1 = """
    match (a:Allocation)-[r1]->(b:Allocation)-[r2]->(a)
    with  a, b, apoc.coll.sort([type(r1),type(r2)]) as types
    return types as typeCombination, count(*) as cnt order by typeCombination
"""
run_cypher(session, q1)
# Out:
# run_cypher : match (a:Allocation)-[r1]->(b:Allocation)-[r2]->(a)    with  a, b, apoc.col...
# Results available after 46ms, finished query after 11300ms
#                                                         cnt
# typeCombination
# [HAS_ACCESSORY_OCC, HAS_CABINET_OCC]                     22
# [HAS_ACCESSORY_OCC, HAS_FRAME_OCC]                       22
# [HAS_ACCESSORY_OCC, HAS_FUNCTION_DESCRIPTION_BL...       48
# [HAS_AREA_FRAME_OCC, HAS_AREA_IDENT_BLOCK]              328
# [HAS_BASE_SHEET, HAS_SHEET_INFO]                       7332
# [HAS_BASE_SHEET, HAS_VOID]                             7318
# [HAS_BR_PIN_OCC, HAS_FUNCTION_OCC]                    47420
# [HAS_BS_INSTANCE, IS_SUCCESSOR]                       24294
# [HAS_CABINET_OCC, HAS_FUNCTION_DESCRIPTION_BLOCK]      2414
# [HAS_CABINET_OCC, HAS_FUNCTION_IDENT_BLOCK]            3950
# [HAS_CABINET_OCC, HAS_LEGEND_HEADER_OCC]                352
# [HAS_CABINET_OCC, HAS_LEGEND_ROW_OCC]                   302
# [HAS_CABINET_OCC, HAS_OCCURRENCE]                        22
# [HAS_CABLE_OCC, HAS_WIRE_PIN_OCC]                      1384
# [HAS_CONN_POINT_OCC, HAS_CONN_SEGM_OCC]              177264
# [HAS_CONN_SEGM_OCC, HAS_NET_OCC]                      86508
# [HAS_DERIVED_DIA_PIN_OCC, HAS_TERM_DIA_DATA_OCC]     324178
# [HAS_DIA_CABLE_BLOCK, HAS_TERM_DIA_HEADER_OCC]         1326
# [HAS_DIA_CONN_PIN_OCC, HAS_DIA_PIN_BLOCK]            108078
# [HAS_DIA_DATA_BLOCK, HAS_DIA_DATA_OCC]                54126
# [HAS_DIA_FOOTER_BLOCK, HAS_DIA_FOOTER_OCC]             1268
# [HAS_DIA_HEADER_BLOCK, HAS_DIA_HEADER_OCC]             1276
# [HAS_EL_PIN_OCC, HAS_FUNCTION_OCC]                   118148
# [HAS_EL_PIN_OCC, HAS_LEGEND_OCC]                       1324
# [HAS_FRAME_OCC, HAS_OCCURRENCE]                        6402
# [HAS_FRAME_OCC, HAS_OCC_CONTAINER]                     3442
# [HAS_FUNCTION_DESCRIPTION_BLOCK, HAS_FUNCTION_OCC]    20226
# [HAS_FUNCTION_DESCRIPTION_BLOCK, HAS_LEGEND_OCC]        470
# [HAS_FUNCTION_IDENT_BLOCK, HAS_FUNCTION_OCC]          42380
# [HAS_FUNCTION_IDENT_BLOCK, HAS_LEGEND_GROUP_OCC]        404
# [HAS_FUNCTION_OCC, HAS_HYDRAULIC_PIN_OCC]               590
# [HAS_FUNCTION_OCC, HAS_MECH_PIN_OCC]                  50574
# [HAS_FUNCTION_OCC, HAS_PNEUMATIC_PIN_OCC]              3668
# [HAS_FUNCTION_OCC, HAS_TERM_GROUP_OCC]                  374
# [HAS_ITEM, HAS_ITEM_OCC]                               4662
# [HAS_ITEM_OCC, HAS_OVERVIEW_OCC]                       4664
# [HAS_LEGEND_GROUP_OCC, HAS_LEGEND_OCC]                  488
# [HAS_LEGEND_GROUP_OCC, HAS_MECH_CONN_SEGM_OCC]           44
# [HAS_LEGEND_HEADER_OCC, HAS_LEGEND_HEADER_OCC]            4
# [HAS_LEGEND_HEADER_OCC, HAS_LEGEND_ROW_OCC]             360
# [HAS_LEGEND_OCC, HAS_MECH_PIN_OCC]                      450
# [HAS_OCCURRENCE, HAS_OCC_CONTAINER]                 1506636
# [HAS_PIN_BLOCK, HAS_PIN_OCC]                         125884
# [HAS_POBJECT, HAS_POBJECT]                           937236
# [HAS_POBJECT, HAS_VOID]                                5958
# [HAS_PV_BASE_ELEMENT, HAS_VOID]                         802
# [HAS_SHEET_DESCRIPTION_BLOCK, HAS_SHEET_INFO_OCC]      4498
# [HAS_SHEET_HISTORY_BLOCK, HAS_SHEET_INFO_OCC]          4414
# [HAS_SHEET_IDENT_BLOCK, HAS_SHEET_INFO_OCC]            4512
# [HAS_SHEET_INFO, HAS_VOID]                             2854
# [HAS_SYMBOL, HAS_SYMBOL_DEF]                           1916
# [HAS_SYMBOL_OCC, HAS_USER_BLOCK]                       9838
# [HAS_SYMBOL_OCC, HAS_USER_DEFINED_TEXT_FIELD_BL...    10740
# [HAS_SYMBOL_OCC, HAS_VOID]                             1912
# [HAS_TEXT_FIELD_BLOCK, HAS_TEXT_FIELD_OCC]          1386866
# [HAS_VOID, IS_SUCCESSOR]                                786
# [IS_SUCCESSOR, IS_SUCCESSOR]                          11068
